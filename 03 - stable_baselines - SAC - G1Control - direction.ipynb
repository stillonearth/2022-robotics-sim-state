# %%
import gym
import numpy as np
import torch

from environments import *

from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.cmd_util import make_vec_env
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /home/user/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/cmd_util.py:5: FutureWarning: Module ``common.cmd_util`` has been renamed to ``common.env_util`` and will be removed in the future.
#   warnings.warn(

# %%
env = make_vec_env("G1ControlEnv-v1", 32, env_kwargs=dict(
    mode='direction',
))
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/gym/core.py:329: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/user/anaconda3/lib/python3.9/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
model = SAC(
    "MlpPolicy", 
    env, 
    verbose=1,
    batch_size=4096,
    buffer_size=1000000,
    policy_kwargs=dict(        
        net_arch=[512, 512, 512, 512], 
        activation_fn=torch.nn.ELU,
        n_critics=5,
    ),
    tensorboard_log="./logs/sac/"
)
# Out:
# Using cuda device

# %%
model.learn(
    total_timesteps=int(1e7), 
    log_interval=100,
    tb_log_name='g1-control-direction',
    reset_num_timesteps=False,
)
# Out:
# Logging to ./logs/sac/g1-control-direction-clean_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -285     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 366      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 12928    |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 23.9     |
# |    ent_coef        | 0.888    |
# |    ent_coef_loss   | -2.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 400      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -233     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 363      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 24256    |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 26.5     |
# |    ent_coef        | 0.799    |
# |    ent_coef_loss   | -4.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 754      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -271     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 362      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 36640    |
# | train/             |          |
# |    actor_loss      | -26.5    |
# |    critic_loss     | 28.5     |
# |    ent_coef        | 0.712    |
# |    ent_coef_loss   | -6.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1141     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -83.6    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 360      |
# |    time_elapsed    | 133      |
# |    total_timesteps | 48128    |
# | train/             |          |
# |    actor_loss      | -30.2    |
# |    critic_loss     | 31.2     |
# |    ent_coef        | 0.641    |
# |    ent_coef_loss   | -8.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1500     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -19.1    |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 358      |
# |    time_elapsed    | 164      |
# |    total_timesteps | 59104    |
# | train/             |          |
# |    actor_loss      | -33.2    |
# |    critic_loss     | 36.5     |
# |    ent_coef        | 0.581    |
# |    ent_coef_loss   | -10      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1843     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | 62.4     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 356      |
# |    time_elapsed    | 197      |
# |    total_timesteps | 70432    |
# | train/             |          |
# |    actor_loss      | -34.6    |
# |    critic_loss     | 43.2     |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2197     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 71.1     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 355      |
# |    time_elapsed    | 230      |
# |    total_timesteps | 81952    |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 65.7     |
# |    ent_coef        | 0.473    |
# |    ent_coef_loss   | -13.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2557     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | 72.8     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 354      |
# |    time_elapsed    | 258      |
# |    total_timesteps | 91584    |
# | train/             |          |
# |    actor_loss      | -36.2    |
# |    critic_loss     | 67.4     |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2858     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 352      |
# |    time_elapsed    | 292      |
# |    total_timesteps | 103392   |
# | train/             |          |
# |    actor_loss      | -38.3    |
# |    critic_loss     | 94.6     |
# |    ent_coef        | 0.392    |
# |    ent_coef_loss   | -15.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3227     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 135      |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 351      |
# |    time_elapsed    | 332      |
# |    total_timesteps | 117056   |
# | train/             |          |
# |    actor_loss      | -37.9    |
# |    critic_loss     | 123      |
# |    ent_coef        | 0.349    |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 350      |
# |    time_elapsed    | 368      |
# |    total_timesteps | 129184   |
# | train/             |          |
# |    actor_loss      | -38.7    |
# |    critic_loss     | 138      |
# |    ent_coef        | 0.315    |
# |    ent_coef_loss   | -16.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4033     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 258      |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 347      |
# |    time_elapsed    | 469      |
# |    total_timesteps | 163008   |
# | train/             |          |
# |    actor_loss      | -40.3    |
# |    critic_loss     | 196      |
# |    ent_coef        | 0.239    |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5090     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | 315      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 346      |
# |    time_elapsed    | 499      |
# |    total_timesteps | 173152   |
# | train/             |          |
# |    actor_loss      | -41      |
# |    critic_loss     | 240      |
# |    ent_coef        | 0.22     |
# |    ent_coef_loss   | -17.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5407     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | 297      |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 346      |
# |    time_elapsed    | 532      |
# |    total_timesteps | 184192   |
# | train/             |          |
# |    actor_loss      | -39.8    |
# |    critic_loss     | 205      |
# |    ent_coef        | 0.202    |
# |    ent_coef_loss   | -17.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5752     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.8     |
# |    ep_rew_mean     | 360      |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 345      |
# |    time_elapsed    | 559      |
# |    total_timesteps | 193312   |
# | train/             |          |
# |    actor_loss      | -41.7    |
# |    critic_loss     | 232      |
# |    ent_coef        | 0.188    |
# |    ent_coef_loss   | -16.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6037     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.6     |
# |    ep_rew_mean     | 364      |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 345      |
# |    time_elapsed    | 588      |
# |    total_timesteps | 203072   |
# | train/             |          |
# |    actor_loss      | -41.7    |
# |    critic_loss     | 225      |
# |    ent_coef        | 0.175    |
# |    ent_coef_loss   | -16.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6342     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.6     |
# |    ep_rew_mean     | 380      |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 344      |
# |    time_elapsed    | 613      |
# |    total_timesteps | 211744   |
# | train/             |          |
# |    actor_loss      | -44.3    |
# |    critic_loss     | 246      |
# |    ent_coef        | 0.163    |
# |    ent_coef_loss   | -17.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6613     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.8     |
# |    ep_rew_mean     | 383      |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 344      |
# |    time_elapsed    | 639      |
# |    total_timesteps | 220352   |
# | train/             |          |
# |    actor_loss      | -44.9    |
# |    critic_loss     | 256      |
# |    ent_coef        | 0.153    |
# |    ent_coef_loss   | -16.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6882     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.7     |
# |    ep_rew_mean     | 412      |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 344      |
# |    time_elapsed    | 668      |
# |    total_timesteps | 230208   |
# | train/             |          |
# |    actor_loss      | -48      |
# |    critic_loss     | 262      |
# |    ent_coef        | 0.142    |
# |    ent_coef_loss   | -15.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7190     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.4     |
# |    ep_rew_mean     | 440      |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 343      |
# |    time_elapsed    | 697      |
# |    total_timesteps | 239936   |
# | train/             |          |
# |    actor_loss      | -44.3    |
# |    critic_loss     | 296      |
# |    ent_coef        | 0.133    |
# |    ent_coef_loss   | -14.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7494     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | 466      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 343      |
# |    time_elapsed    | 725      |
# |    total_timesteps | 249536   |
# | train/             |          |
# |    actor_loss      | -45      |
# |    critic_loss     | 263      |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -14.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7794     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90       |
# |    ep_rew_mean     | 487      |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 343      |
# |    time_elapsed    | 751      |
# |    total_timesteps | 258208   |
# | train/             |          |
# |    actor_loss      | -48.1    |
# |    critic_loss     | 284      |
# |    ent_coef        | 0.116    |
# |    ent_coef_loss   | -12.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8065     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.9     |
# |    ep_rew_mean     | 506      |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 343      |
# |    time_elapsed    | 779      |
# |    total_timesteps | 267648   |
# | train/             |          |
# |    actor_loss      | -48.2    |
# |    critic_loss     | 276      |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | -13.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8360     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.5     |
# |    ep_rew_mean     | 497      |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 343      |
# |    time_elapsed    | 805      |
# |    total_timesteps | 276288   |
# | train/             |          |
# |    actor_loss      | -52.9    |
# |    critic_loss     | 311      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -12.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8630     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.9     |
# |    ep_rew_mean     | 500      |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 342      |
# |    time_elapsed    | 831      |
# |    total_timesteps | 284992   |
# | train/             |          |
# |    actor_loss      | -51.8    |
# |    critic_loss     | 323      |
# |    ent_coef        | 0.0971   |
# |    ent_coef_loss   | -10.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8902     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.8     |
# |    ep_rew_mean     | 543      |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 342      |
# |    time_elapsed    | 858      |
# |    total_timesteps | 294208   |
# | train/             |          |
# |    actor_loss      | -56.1    |
# |    critic_loss     | 291      |
# |    ent_coef        | 0.0915   |
# |    ent_coef_loss   | -9.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9190     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.9     |
# |    ep_rew_mean     | 552      |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 342      |
# |    time_elapsed    | 884      |
# |    total_timesteps | 302944   |
# | train/             |          |
# |    actor_loss      | -58.1    |
# |    critic_loss     | 303      |
# |    ent_coef        | 0.0867   |
# |    ent_coef_loss   | -9.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9463     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.5     |
# |    ep_rew_mean     | 561      |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 342      |
# |    time_elapsed    | 911      |
# |    total_timesteps | 311872   |
# | train/             |          |
# |    actor_loss      | -60.9    |
# |    critic_loss     | 298      |
# |    ent_coef        | 0.0823   |
# |    ent_coef_loss   | -8.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9742     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.1     |
# |    ep_rew_mean     | 563      |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 342      |
# |    time_elapsed    | 937      |
# |    total_timesteps | 320672   |
# | train/             |          |
# |    actor_loss      | -60.3    |
# |    critic_loss     | 309      |
# |    ent_coef        | 0.0784   |
# |    ent_coef_loss   | -7.52    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10017    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.7     |
# |    ep_rew_mean     | 549      |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 341      |
# |    time_elapsed    | 965      |
# |    total_timesteps | 330272   |
# | train/             |          |
# |    actor_loss      | -65      |
# |    critic_loss     | 312      |
# |    ent_coef        | 0.0745   |
# |    ent_coef_loss   | -7.34    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10317    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.9     |
# |    ep_rew_mean     | 503      |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 341      |
# |    time_elapsed    | 988      |
# |    total_timesteps | 337760   |
# | train/             |          |
# |    actor_loss      | -66      |
# |    critic_loss     | 295      |
# |    ent_coef        | 0.0717   |
# |    ent_coef_loss   | -6.37    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10551    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.5     |
# |    ep_rew_mean     | 520      |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 341      |
# |    time_elapsed    | 1012     |
# |    total_timesteps | 345952   |
# | train/             |          |
# |    actor_loss      | -67.8    |
# |    critic_loss     | 314      |
# |    ent_coef        | 0.0689   |
# |    ent_coef_loss   | -4.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10807    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.8     |
# |    ep_rew_mean     | 549      |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 341      |
# |    time_elapsed    | 1038     |
# |    total_timesteps | 354720   |
# | train/             |          |
# |    actor_loss      | -72.3    |
# |    critic_loss     | 317      |
# |    ent_coef        | 0.0665   |
# |    ent_coef_loss   | -4.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.3     |
# |    ep_rew_mean     | 675      |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 341      |
# |    time_elapsed    | 1065     |
# |    total_timesteps | 363904   |
# | train/             |          |
# |    actor_loss      | -75.6    |
# |    critic_loss     | 306      |
# |    ent_coef        | 0.0642   |
# |    ent_coef_loss   | -2.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11368    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.2     |
# |    ep_rew_mean     | 669      |
# | time/              |          |
# |    episodes        | 3700     |
# |    fps             | 341      |
# |    time_elapsed    | 1094     |
# |    total_timesteps | 373664   |
# | train/             |          |
# |    actor_loss      | -77.6    |
# |    critic_loss     | 325      |
# |    ent_coef        | 0.0621   |
# |    ent_coef_loss   | -1.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11673    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.6     |
# |    ep_rew_mean     | 711      |
# | time/              |          |
# |    episodes        | 3800     |
# |    fps             | 341      |
# |    time_elapsed    | 1122     |
# |    total_timesteps | 383008   |
# | train/             |          |
# |    actor_loss      | -80.8    |
# |    critic_loss     | 315      |
# |    ent_coef        | 0.0607   |
# |    ent_coef_loss   | -0.652   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11965    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | 772      |
# | time/              |          |
# |    episodes        | 3900     |
# |    fps             | 341      |
# |    time_elapsed    | 1154     |
# |    total_timesteps | 393984   |
# | train/             |          |
# |    actor_loss      | -80.2    |
# |    critic_loss     | 323      |
# |    ent_coef        | 0.0597   |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12308    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.5     |
# |    ep_rew_mean     | 627      |
# | time/              |          |
# |    episodes        | 4000     |
# |    fps             | 341      |
# |    time_elapsed    | 1180     |
# |    total_timesteps | 402720   |
# | train/             |          |
# |    actor_loss      | -79.9    |
# |    critic_loss     | 318      |
# |    ent_coef        | 0.0591   |
# |    ent_coef_loss   | -0.594   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | 736      |
# | time/              |          |
# |    episodes        | 4100     |
# |    fps             | 340      |
# |    time_elapsed    | 1212     |
# |    total_timesteps | 413504   |
# | train/             |          |
# |    actor_loss      | -87.1    |
# |    critic_loss     | 348      |
# |    ent_coef        | 0.059    |
# |    ent_coef_loss   | -0.496   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12918    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | 780      |
# | time/              |          |
# |    episodes        | 4200     |
# |    fps             | 340      |
# |    time_elapsed    | 1244     |
# |    total_timesteps | 424224   |
# | train/             |          |
# |    actor_loss      | -90.3    |
# |    critic_loss     | 342      |
# |    ent_coef        | 0.059    |
# |    ent_coef_loss   | 0.705    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13253    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | 881      |
# | time/              |          |
# |    episodes        | 4300     |
# |    fps             | 340      |
# |    time_elapsed    | 1275     |
# |    total_timesteps | 434720   |
# | train/             |          |
# |    actor_loss      | -93.5    |
# |    critic_loss     | 349      |
# |    ent_coef        | 0.0598   |
# |    ent_coef_loss   | 2.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 997      |
# | time/              |          |
# |    episodes        | 4400     |
# |    fps             | 340      |
# |    time_elapsed    | 1312     |
# |    total_timesteps | 447200   |
# | train/             |          |
# |    actor_loss      | -97.2    |
# |    critic_loss     | 348      |
# |    ent_coef        | 0.0605   |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13971    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 1.03e+03 |
# | time/              |          |
# |    episodes        | 4500     |
# |    fps             | 340      |
# |    time_elapsed    | 1349     |
# |    total_timesteps | 459648   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 344      |
# |    ent_coef        | 0.0612   |
# |    ent_coef_loss   | -0.887   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14360    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | 1e+03    |
# | time/              |          |
# |    episodes        | 4600     |
# |    fps             | 340      |
# |    time_elapsed    | 1385     |
# |    total_timesteps | 471680   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 382      |
# |    ent_coef        | 0.0622   |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14736    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 1.11e+03 |
# | time/              |          |
# |    episodes        | 4700     |
# |    fps             | 340      |
# |    time_elapsed    | 1422     |
# |    total_timesteps | 484384   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 349      |
# |    ent_coef        | 0.0636   |
# |    ent_coef_loss   | 0.731    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15133    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 1.13e+03 |
# | time/              |          |
# |    episodes        | 4800     |
# |    fps             | 340      |
# |    time_elapsed    | 1464     |
# |    total_timesteps | 498464   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 378      |
# |    ent_coef        | 0.0641   |
# |    ent_coef_loss   | 0.48     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15573    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 4900     |
# |    fps             | 340      |
# |    time_elapsed    | 1506     |
# |    total_timesteps | 512704   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 371      |
# |    ent_coef        | 0.0644   |
# |    ent_coef_loss   | 0.723    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16018    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 5000     |
# |    fps             | 340      |
# |    time_elapsed    | 1546     |
# |    total_timesteps | 526144   |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 364      |
# |    ent_coef        | 0.0654   |
# |    ent_coef_loss   | -0.905   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16438    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 1.07e+03 |
# | time/              |          |
# |    episodes        | 5100     |
# |    fps             | 340      |
# |    time_elapsed    | 1582     |
# |    total_timesteps | 538272   |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 382      |
# |    ent_coef        | 0.0652   |
# |    ent_coef_loss   | -0.109   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16817    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 158      |
# |    ep_rew_mean     | 1.49e+03 |
# | time/              |          |
# |    episodes        | 5200     |
# |    fps             | 339      |
# |    time_elapsed    | 1629     |
# |    total_timesteps | 554016   |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 356      |
# |    ent_coef        | 0.0675   |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17309    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 153      |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 5300     |
# |    fps             | 339      |
# |    time_elapsed    | 1681     |
# |    total_timesteps | 571456   |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 368      |
# |    ent_coef        | 0.0687   |
# |    ent_coef_loss   | 0.93     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17854    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | 1.86e+03 |
# | time/              |          |
# |    episodes        | 5400     |
# |    fps             | 339      |
# |    time_elapsed    | 1731     |
# |    total_timesteps | 588256   |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 417      |
# |    ent_coef        | 0.072    |
# |    ent_coef_loss   | -0.712   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18379    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 182      |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 5500     |
# |    fps             | 339      |
# |    time_elapsed    | 1788     |
# |    total_timesteps | 607744   |
# | train/             |          |
# |    actor_loss      | -149     |
# |    critic_loss     | 391      |
# |    ent_coef        | 0.0727   |
# |    ent_coef_loss   | 0.207    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18988    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 5600     |
# |    fps             | 339      |
# |    time_elapsed    | 1853     |
# |    total_timesteps | 629408   |
# | train/             |          |
# |    actor_loss      | -157     |
# |    critic_loss     | 383      |
# |    ent_coef        | 0.0747   |
# |    ent_coef_loss   | 0.0986   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19665    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 2.61e+03 |
# | time/              |          |
# |    episodes        | 5700     |
# |    fps             | 339      |
# |    time_elapsed    | 1923     |
# |    total_timesteps | 653120   |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 378      |
# |    ent_coef        | 0.076    |
# |    ent_coef_loss   | 0.516    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20406    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 260      |
# |    ep_rew_mean     | 3.06e+03 |
# | time/              |          |
# |    episodes        | 5800     |
# |    fps             | 339      |
# |    time_elapsed    | 2004     |
# |    total_timesteps | 680256   |
# | train/             |          |
# |    actor_loss      | -177     |
# |    critic_loss     | 401      |
# |    ent_coef        | 0.0798   |
# |    ent_coef_loss   | 0.145    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21254    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 3.92e+03 |
# | time/              |          |
# |    episodes        | 5900     |
# |    fps             | 339      |
# |    time_elapsed    | 2091     |
# |    total_timesteps | 709728   |
# | train/             |          |
# |    actor_loss      | -199     |
# |    critic_loss     | 395      |
# |    ent_coef        | 0.082    |
# |    ent_coef_loss   | 0.776    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22175    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 352      |
# |    ep_rew_mean     | 5.11e+03 |
# | time/              |          |
# |    episodes        | 6000     |
# |    fps             | 339      |
# |    time_elapsed    | 2202     |
# |    total_timesteps | 747232   |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 400      |
# |    ent_coef        | 0.0863   |
# |    ent_coef_loss   | 0.171    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23347    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 381      |
# |    ep_rew_mean     | 5.96e+03 |
# | time/              |          |
# |    episodes        | 6100     |
# |    fps             | 339      |
# |    time_elapsed    | 2315     |
# |    total_timesteps | 785088   |
# | train/             |          |
# |    actor_loss      | -249     |
# |    critic_loss     | 706      |
# |    ent_coef        | 0.0916   |
# |    ent_coef_loss   | 0.592    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24530    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 430      |
# |    ep_rew_mean     | 7.28e+03 |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 338      |
# |    time_elapsed    | 2441     |
# |    total_timesteps | 827488   |
# | train/             |          |
# |    actor_loss      | -276     |
# |    critic_loss     | 1.38e+03 |
# |    ent_coef        | 0.0967   |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25855    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 453      |
# |    ep_rew_mean     | 7.68e+03 |
# | time/              |          |
# |    episodes        | 6300     |
# |    fps             | 338      |
# |    time_elapsed    | 2573     |
# |    total_timesteps | 872128   |
# | train/             |          |
# |    actor_loss      | -308     |
# |    critic_loss     | 502      |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | -0.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27250    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 460      |
# |    ep_rew_mean     | 7.82e+03 |
# | time/              |          |
# |    episodes        | 6400     |
# |    fps             | 338      |
# |    time_elapsed    | 2710     |
# |    total_timesteps | 918016   |
# | train/             |          |
# |    actor_loss      | -340     |
# |    critic_loss     | 715      |
# |    ent_coef        | 0.11     |
# |    ent_coef_loss   | 0.484    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28684    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 457      |
# |    ep_rew_mean     | 8.45e+03 |
# | time/              |          |
# |    episodes        | 6500     |
# |    fps             | 338      |
# |    time_elapsed    | 2848     |
# |    total_timesteps | 964416   |
# | train/             |          |
# |    actor_loss      | -378     |
# |    critic_loss     | 806      |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | -0.634   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30134    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 488      |
# |    ep_rew_mean     | 9.37e+03 |
# | time/              |          |
# |    episodes        | 6600     |
# |    fps             | 338      |
# |    time_elapsed    | 2995     |
# |    total_timesteps | 1013600  |
# | train/             |          |
# |    actor_loss      | -417     |
# |    critic_loss     | 1.42e+03 |
# |    ent_coef        | 0.121    |
# |    ent_coef_loss   | 0.733    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31671    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 482      |
# |    ep_rew_mean     | 9.7e+03  |
# | time/              |          |
# |    episodes        | 6700     |
# |    fps             | 338      |
# |    time_elapsed    | 3137     |
# |    total_timesteps | 1061152  |
# | train/             |          |
# |    actor_loss      | -482     |
# |    critic_loss     | 1.16e+03 |
# |    ent_coef        | 0.128    |
# |    ent_coef_loss   | 0.487    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33157    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 498      |
# |    ep_rew_mean     | 1.02e+04 |
# | time/              |          |
# |    episodes        | 6800     |
# |    fps             | 338      |
# |    time_elapsed    | 3284     |
# |    total_timesteps | 1110688  |
# | train/             |          |
# |    actor_loss      | -525     |
# |    critic_loss     | 1.64e+03 |
# |    ent_coef        | 0.137    |
# |    ent_coef_loss   | 0.483    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34705    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 486      |
# |    ep_rew_mean     | 1.06e+04 |
# | time/              |          |
# |    episodes        | 6900     |
# |    fps             | 338      |
# |    time_elapsed    | 3428     |
# |    total_timesteps | 1158880  |
# | train/             |          |
# |    actor_loss      | -586     |
# |    critic_loss     | 1.78e+03 |
# |    ent_coef        | 0.146    |
# |    ent_coef_loss   | -0.484   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36211    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 480      |
# |    ep_rew_mean     | 1.05e+04 |
# | time/              |          |
# |    episodes        | 7000     |
# |    fps             | 337      |
# |    time_elapsed    | 3569     |
# |    total_timesteps | 1206368  |
# | train/             |          |
# |    actor_loss      | -638     |
# |    critic_loss     | 2.45e+03 |
# |    ent_coef        | 0.154    |
# |    ent_coef_loss   | 0.516    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37695    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 482      |
# |    ep_rew_mean     | 1.06e+04 |
# | time/              |          |
# |    episodes        | 7100     |
# |    fps             | 337      |
# |    time_elapsed    | 3713     |
# |    total_timesteps | 1254912  |
# | train/             |          |
# |    actor_loss      | -699     |
# |    critic_loss     | 3.85e+03 |
# |    ent_coef        | 0.166    |
# |    ent_coef_loss   | 0.2      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39212    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 491      |
# |    ep_rew_mean     | 1.14e+04 |
# | time/              |          |
# |    episodes        | 7200     |
# |    fps             | 337      |
# |    time_elapsed    | 3865     |
# |    total_timesteps | 1305600  |
# | train/             |          |
# |    actor_loss      | -756     |
# |    critic_loss     | 6.09e+03 |
# |    ent_coef        | 0.183    |
# |    ent_coef_loss   | -0.186   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40796    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 497      |
# |    ep_rew_mean     | 1.17e+04 |
# | time/              |          |
# |    episodes        | 7300     |
# |    fps             | 337      |
# |    time_elapsed    | 4011     |
# |    total_timesteps | 1354816  |
# | train/             |          |
# |    actor_loss      | -821     |
# |    critic_loss     | 3.45e+03 |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | 0.453    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 497      |
# |    ep_rew_mean     | 1.16e+04 |
# | time/              |          |
# |    episodes        | 7400     |
# |    fps             | 337      |
# |    time_elapsed    | 4156     |
# |    total_timesteps | 1403392  |
# | train/             |          |
# |    actor_loss      | -890     |
# |    critic_loss     | 3.15e+03 |
# |    ent_coef        | 0.208    |
# |    ent_coef_loss   | -0.188   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43852    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 7500     |
# |    fps             | 337      |
# |    time_elapsed    | 4300     |
# |    total_timesteps | 1451584  |
# | train/             |          |
# |    actor_loss      | -946     |
# |    critic_loss     | 8.84e+03 |
# |    ent_coef        | 0.219    |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45358    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 496      |
# |    ep_rew_mean     | 1.2e+04  |
# | time/              |          |
# |    episodes        | 7600     |
# |    fps             | 337      |
# |    time_elapsed    | 4453     |
# |    total_timesteps | 1503104  |
# | train/             |          |
# |    actor_loss      | -990     |
# |    critic_loss     | 7.59e+03 |
# |    ent_coef        | 0.239    |
# |    ent_coef_loss   | -0.572   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46968    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 494       |
# |    ep_rew_mean     | 1.24e+04  |
# | time/              |           |
# |    episodes        | 7700      |
# |    fps             | 337       |
# |    time_elapsed    | 4603      |
# |    total_timesteps | 1553536   |
# | train/             |           |
# |    actor_loss      | -1.05e+03 |
# |    critic_loss     | 4.52e+03  |
# |    ent_coef        | 0.241     |
# |    ent_coef_loss   | -0.429    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 48544     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 493       |
# |    ep_rew_mean     | 1.23e+04  |
# | time/              |           |
# |    episodes        | 7800      |
# |    fps             | 337       |
# |    time_elapsed    | 4751      |
# |    total_timesteps | 1603360   |
# | train/             |           |
# |    actor_loss      | -1.11e+03 |
# |    critic_loss     | 5.31e+03  |
# |    ent_coef        | 0.254     |
# |    ent_coef_loss   | -0.22     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 50101     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 494       |
# |    ep_rew_mean     | 1.24e+04  |
# | time/              |           |
# |    episodes        | 7900      |
# |    fps             | 337       |
# |    time_elapsed    | 4897      |
# |    total_timesteps | 1652320   |
# | train/             |           |
# |    actor_loss      | -1.15e+03 |
# |    critic_loss     | 4.91e+03  |
# |    ent_coef        | 0.255     |
# |    ent_coef_loss   | 0.353     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 51631     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 498       |
# |    ep_rew_mean     | 1.28e+04  |
# | time/              |           |
# |    episodes        | 8000      |
# |    fps             | 337       |
# |    time_elapsed    | 5045      |
# |    total_timesteps | 1702144   |
# | train/             |           |
# |    actor_loss      | -1.18e+03 |
# |    critic_loss     | 4.48e+03  |
# |    ent_coef        | 0.267     |
# |    ent_coef_loss   | -0.738    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 53188     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 480       |
# |    ep_rew_mean     | 1.24e+04  |
# | time/              |           |
# |    episodes        | 8100      |
# |    fps             | 337       |
# |    time_elapsed    | 5188      |
# |    total_timesteps | 1750144   |
# | train/             |           |
# |    actor_loss      | -1.22e+03 |
# |    critic_loss     | 1.09e+04  |
# |    ent_coef        | 0.276     |
# |    ent_coef_loss   | 0.466     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 54688     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 488       |
# |    ep_rew_mean     | 1.26e+04  |
# | time/              |           |
# |    episodes        | 8200      |
# |    fps             | 337       |
# |    time_elapsed    | 5334      |
# |    total_timesteps | 1799168   |
# | train/             |           |
# |    actor_loss      | -1.24e+03 |
# |    critic_loss     | 1.29e+04  |
# |    ent_coef        | 0.291     |
# |    ent_coef_loss   | -0.00766  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 56220     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 491       |
# |    ep_rew_mean     | 1.3e+04   |
# | time/              |           |
# |    episodes        | 8300      |
# |    fps             | 337       |
# |    time_elapsed    | 5479      |
# |    total_timesteps | 1847936   |
# | train/             |           |
# |    actor_loss      | -1.28e+03 |
# |    critic_loss     | 1.01e+04  |
# |    ent_coef        | 0.287     |
# |    ent_coef_loss   | 0.167     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 57744     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 473       |
# |    ep_rew_mean     | 1.29e+04  |
# | time/              |           |
# |    episodes        | 8400      |
# |    fps             | 337       |
# |    time_elapsed    | 5620      |
# |    total_timesteps | 1895296   |
# | train/             |           |
# |    actor_loss      | -1.31e+03 |
# |    critic_loss     | 4.19e+03  |
# |    ent_coef        | 0.297     |
# |    ent_coef_loss   | 0.341     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 59224     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 485       |
# |    ep_rew_mean     | 1.27e+04  |
# | time/              |           |
# |    episodes        | 8500      |
# |    fps             | 337       |
# |    time_elapsed    | 5763      |
# |    total_timesteps | 1943488   |
# | train/             |           |
# |    actor_loss      | -1.32e+03 |
# ...
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 404       |
# |    ep_rew_mean     | 1.56e+04  |
# | time/              |           |
# |    episodes        | 23600     |
# |    fps             | 337       |
# |    time_elapsed    | 26469     |
# |    total_timesteps | 8940896   |
# | train/             |           |
# |    actor_loss      | -1.62e+03 |
# |    critic_loss     | 1.7e+04   |
# |    ent_coef        | 0.624     |
# |    ent_coef_loss   | 0.0528    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 279399    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 431       |
# |    ep_rew_mean     | 1.65e+04  |
# | time/              |           |
# |    episodes        | 23700     |
# |    fps             | 337       |
# |    time_elapsed    | 26597     |
# |    total_timesteps | 8984288   |
# | train/             |           |
# |    actor_loss      | -1.61e+03 |
# |    critic_loss     | 1.36e+04  |
# |    ent_coef        | 0.62      |
# |    ent_coef_loss   | -0.00844  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 280755    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 445       |
# |    ep_rew_mean     | 1.73e+04  |
# | time/              |           |
# |    episodes        | 23800     |
# |    fps             | 337       |
# |    time_elapsed    | 26727     |
# |    total_timesteps | 9028256   |
# | train/             |           |
# |    actor_loss      | -1.59e+03 |
# |    critic_loss     | 7.95e+03  |
# |    ent_coef        | 0.628     |
# |    ent_coef_loss   | 0.013     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 282129    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 388       |
# |    ep_rew_mean     | 1.49e+04  |
# | time/              |           |
# |    episodes        | 23900     |
# |    fps             | 337       |
# |    time_elapsed    | 26843     |
# |    total_timesteps | 9067456   |
# | train/             |           |
# |    actor_loss      | -1.61e+03 |
# |    critic_loss     | 1.43e+04  |
# |    ent_coef        | 0.618     |
# |    ent_coef_loss   | 0.0742    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 283354    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | 1.52e+04 |
# | time/              |          |
# |    episodes        | 24000    |
# |    fps             | 337      |
# |    time_elapsed    | 26956    |
# |    total_timesteps | 9105792  |
# | train/             |          |
# |    actor_loss      | -1.6e+03 |
# |    critic_loss     | 1.87e+04 |
# |    ent_coef        | 0.623    |
# |    ent_coef_loss   | -0.0307  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 284552   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 393      |
# |    ep_rew_mean     | 1.55e+04 |
# | time/              |          |
# |    episodes        | 24100    |
# |    fps             | 337      |
# |    time_elapsed    | 27069    |
# |    total_timesteps | 9144000  |
# | train/             |          |
# |    actor_loss      | -1.6e+03 |
# |    critic_loss     | 1.34e+04 |
# |    ent_coef        | 0.61     |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 285746   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 398      |
# |    ep_rew_mean     | 1.55e+04 |
# | time/              |          |
# |    episodes        | 24200    |
# |    fps             | 337      |
# |    time_elapsed    | 27189    |
# |    total_timesteps | 9184512  |
# | train/             |          |
# |    actor_loss      | -1.6e+03 |
# |    critic_loss     | 1.31e+04 |
# |    ent_coef        | 0.61     |
# |    ent_coef_loss   | 0.204    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 287012   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 415      |
# |    ep_rew_mean     | 1.63e+04 |
# | time/              |          |
# |    episodes        | 24300    |
# |    fps             | 337      |
# |    time_elapsed    | 27311    |
# |    total_timesteps | 9225856  |
# | train/             |          |
# |    actor_loss      | -1.6e+03 |
# |    critic_loss     | 1.31e+04 |
# |    ent_coef        | 0.609    |
# |    ent_coef_loss   | -0.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 288304   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 431       |
# |    ep_rew_mean     | 1.74e+04  |
# | time/              |           |
# |    episodes        | 24400     |
# |    fps             | 337       |
# |    time_elapsed    | 27438     |
# |    total_timesteps | 9268960   |
# | train/             |           |
# |    actor_loss      | -1.64e+03 |
# |    critic_loss     | 9.42e+03  |
# |    ent_coef        | 0.596     |
# |    ent_coef_loss   | 0.185     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 289651    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 376       |
# |    ep_rew_mean     | 1.45e+04  |
# | time/              |           |
# |    episodes        | 24500     |
# |    fps             | 337       |
# |    time_elapsed    | 27549     |
# |    total_timesteps | 9306720   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 1.1e+04   |
# |    ent_coef        | 0.591     |
# |    ent_coef_loss   | -0.167    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 290831    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 374       |
# |    ep_rew_mean     | 1.47e+04  |
# | time/              |           |
# |    episodes        | 24600     |
# |    fps             | 337       |
# |    time_elapsed    | 27659     |
# |    total_timesteps | 9343808   |
# | train/             |           |
# |    actor_loss      | -1.62e+03 |
# |    critic_loss     | 1.59e+04  |
# |    ent_coef        | 0.597     |
# |    ent_coef_loss   | 0.0472    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 291990    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 409       |
# |    ep_rew_mean     | 1.62e+04  |
# | time/              |           |
# |    episodes        | 24700     |
# |    fps             | 337       |
# |    time_elapsed    | 27781     |
# |    total_timesteps | 9385312   |
# | train/             |           |
# |    actor_loss      | -1.64e+03 |
# |    critic_loss     | 1.46e+04  |
# |    ent_coef        | 0.604     |
# |    ent_coef_loss   | 0.035     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 293287    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 402       |
# |    ep_rew_mean     | 1.57e+04  |
# | time/              |           |
# |    episodes        | 24800     |
# |    fps             | 337       |
# |    time_elapsed    | 27899     |
# |    total_timesteps | 9425248   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 5.17e+03  |
# |    ent_coef        | 0.592     |
# |    ent_coef_loss   | -0.0422   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 294535    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 417       |
# |    ep_rew_mean     | 1.64e+04  |
# | time/              |           |
# |    episodes        | 24900     |
# |    fps             | 337       |
# |    time_elapsed    | 28022     |
# |    total_timesteps | 9467008   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 1.74e+04  |
# |    ent_coef        | 0.608     |
# |    ent_coef_loss   | 0.116     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 295840    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 402       |
# |    ep_rew_mean     | 1.55e+04  |
# | time/              |           |
# |    episodes        | 25000     |
# |    fps             | 337       |
# |    time_elapsed    | 28142     |
# |    total_timesteps | 9507584   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 1.5e+04   |
# |    ent_coef        | 0.609     |
# |    ent_coef_loss   | 0.11      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 297108    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 386       |
# |    ep_rew_mean     | 1.52e+04  |
# | time/              |           |
# |    episodes        | 25100     |
# |    fps             | 337       |
# |    time_elapsed    | 28253     |
# |    total_timesteps | 9545184   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 1.44e+04  |
# |    ent_coef        | 0.612     |
# |    ent_coef_loss   | -0.111    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 298283    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 360       |
# |    ep_rew_mean     | 1.34e+04  |
# | time/              |           |
# |    episodes        | 25200     |
# |    fps             | 337       |
# |    time_elapsed    | 28363     |
# |    total_timesteps | 9582528   |
# | train/             |           |
# |    actor_loss      | -1.64e+03 |
# |    critic_loss     | 4.22e+03  |
# |    ent_coef        | 0.623     |
# |    ent_coef_loss   | -0.212    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 299450    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 407       |
# |    ep_rew_mean     | 1.6e+04   |
# | time/              |           |
# |    episodes        | 25300     |
# |    fps             | 337       |
# |    time_elapsed    | 28481     |
# |    total_timesteps | 9622528   |
# | train/             |           |
# |    actor_loss      | -1.64e+03 |
# |    critic_loss     | 1.3e+04   |
# |    ent_coef        | 0.627     |
# |    ent_coef_loss   | -0.134    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 300700    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 418       |
# |    ep_rew_mean     | 1.63e+04  |
# | time/              |           |
# |    episodes        | 25400     |
# |    fps             | 337       |
# |    time_elapsed    | 28605     |
# |    total_timesteps | 9664160   |
# | train/             |           |
# |    actor_loss      | -1.65e+03 |
# |    critic_loss     | 1.33e+04  |
# |    ent_coef        | 0.63      |
# |    ent_coef_loss   | 0.0853    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 302001    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 421       |
# |    ep_rew_mean     | 1.65e+04  |
# | time/              |           |
# |    episodes        | 25500     |
# |    fps             | 337       |
# |    time_elapsed    | 28727     |
# |    total_timesteps | 9705696   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 8.92e+03  |
# |    ent_coef        | 0.633     |
# |    ent_coef_loss   | -0.114    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 303299    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 378       |
# |    ep_rew_mean     | 1.49e+04  |
# | time/              |           |
# |    episodes        | 25600     |
# |    fps             | 337       |
# |    time_elapsed    | 28841     |
# |    total_timesteps | 9744448   |
# | train/             |           |
# |    actor_loss      | -1.61e+03 |
# |    critic_loss     | 7.6e+03   |
# |    ent_coef        | 0.632     |
# |    ent_coef_loss   | 0.022     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 304510    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 385       |
# |    ep_rew_mean     | 1.5e+04   |
# | time/              |           |
# |    episodes        | 25700     |
# |    fps             | 337       |
# |    time_elapsed    | 28955     |
# |    total_timesteps | 9782880   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 1.6e+04   |
# |    ent_coef        | 0.628     |
# |    ent_coef_loss   | -0.145    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 305711    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 380       |
# |    ep_rew_mean     | 1.48e+04  |
# | time/              |           |
# |    episodes        | 25800     |
# |    fps             | 337       |
# |    time_elapsed    | 29064     |
# |    total_timesteps | 9819712   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 1.06e+04  |
# |    ent_coef        | 0.63      |
# |    ent_coef_loss   | -0.186    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 306862    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 398       |
# |    ep_rew_mean     | 1.53e+04  |
# | time/              |           |
# |    episodes        | 25900     |
# |    fps             | 337       |
# |    time_elapsed    | 29184     |
# |    total_timesteps | 9860384   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 9.93e+03  |
# |    ent_coef        | 0.624     |
# |    ent_coef_loss   | -0.103    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 308133    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 361       |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 26000     |
# |    fps             | 337       |
# |    time_elapsed    | 29290     |
# |    total_timesteps | 9896160   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 1.3e+04   |
# |    ent_coef        | 0.621     |
# |    ent_coef_loss   | -0.085    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 309251    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 389       |
# |    ep_rew_mean     | 1.52e+04  |
# | time/              |           |
# |    episodes        | 26100     |
# |    fps             | 337       |
# |    time_elapsed    | 29404     |
# |    total_timesteps | 9934720   |
# | train/             |           |
# |    actor_loss      | -1.64e+03 |
# |    critic_loss     | 7.07e+03  |
# |    ent_coef        | 0.617     |
# |    ent_coef_loss   | 0.0949    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 310456    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 374       |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 26200     |
# |    fps             | 337       |
# |    time_elapsed    | 29516     |
# |    total_timesteps | 9972672   |
# | train/             |           |
# |    actor_loss      | -1.63e+03 |
# |    critic_loss     | 1.07e+04  |
# |    ent_coef        | 0.627     |
# |    ent_coef_loss   | -0.074    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 311642    |
# ----------------------------------

# %%
model.save("trained_models/g1-control/direction")
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:276: UserWarning: Path 'trained_models/g1-control' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
