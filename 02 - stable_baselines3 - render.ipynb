# %%
import imageio
import numpy as np
import torch

from stable_baselines3 import SAC

from environments import *

model = SAC(
    "MlpPolicy", 
    "G1Dist-v0", 
    verbose=1,
    policy_kwargs=dict(
        net_arch=[512, 512, 512, 512], 
        activation_fn=torch.nn.ELU,
    ),
    batch_size=1024,
    buffer_size=100000,
)
model.load("g1")

images = []
obs = model.env.reset()
img = model.env.render(mode='rgb_array')
for i in range(350):
    images.append(img)
    action, _ = model.predict(obs)
    obs, _, _ ,_ = model.env.step(action)
    img = model.env.render(mode='rgb_array')

imageio.mimsave('lander_a2c.gif', [np.array(img) for i, img in enumerate(images) if i%2 == 0], fps=29)
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# Using cuda device
# Creating environment from the given name 'G1Dist-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/user/anaconda3/lib/python3.9/site-packages/gym/core.py:329: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/user/anaconda3/lib/python3.9/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/user/anaconda3/lib/python3.9/site-packages/gym/core.py:51: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /home/user/anaconda3/lib/python3.9/site-packages/glfw/__init__.py:906: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# /home/user/anaconda3/lib/python3.9/site-packages/glfw/__init__.py:906: GLFWError: (65537) b'The GLFW library is not initialized'
#   warnings.warn(message, GLFWError)
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# Input In [1], in <cell line: 24>()
#      22 images = []
#      23 obs = model.env.reset()
# ---> 24 img = model.env.render(mode='rgb_array')
#      25 for i in range(350):
#      26     images.append(img)
#
# File ~/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:87, in DummyVecEnv.render(self, mode)
#      75 """
#      76 Gym environment rendering. If there are multiple environments then
#      77 they are tiled together in one image via ``BaseVecEnv.render()``.
#    (...)
#      84 :param mode: The rendering type.
#      85 """
#      86 if self.num_envs == 1:
# ---> 87     return self.envs[0].render(mode=mode)
#      88 else:
#      89     return super().render(mode=mode)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:66, in _EnvDecorator._deprecate_mode.<locals>.render(self, *args, **kwargs)
#      56 elif self.spec is not None and "render_mode" not in self.spec.kwargs.keys():  # type: ignore
#      57     deprecation(
#      58         "You are calling render method, "
#      59         "but you didn't specified the argument render_mode at environment initialization. "
#    (...)
#      63         "See here for more information: https://www.gymlibrary.ml/content/api/"
#      64     )
# ---> 66 return render_func(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:431, in Wrapper.render(self, *args, **kwargs)
#     429 def render(self, *args, **kwargs):
#     430     """Renders the environment."""
# --> 431     return self.env.render(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:66, in _EnvDecorator._deprecate_mode.<locals>.render(self, *args, **kwargs)
#      56 elif self.spec is not None and "render_mode" not in self.spec.kwargs.keys():  # type: ignore
#      57     deprecation(
#      58         "You are calling render method, "
#      59         "but you didn't specified the argument render_mode at environment initialization. "
#    (...)
#      63         "See here for more information: https://www.gymlibrary.ml/content/api/"
#      64     )
# ---> 66 return render_func(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:431, in Wrapper.render(self, *args, **kwargs)
#     429 def render(self, *args, **kwargs):
#     430     """Renders the environment."""
# --> 431     return self.env.render(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:66, in _EnvDecorator._deprecate_mode.<locals>.render(self, *args, **kwargs)
#      56 elif self.spec is not None and "render_mode" not in self.spec.kwargs.keys():  # type: ignore
#      57     deprecation(
#      58         "You are calling render method, "
#      59         "but you didn't specified the argument render_mode at environment initialization. "
#    (...)
#      63         "See here for more information: https://www.gymlibrary.ml/content/api/"
#      64     )
# ---> 66 return render_func(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/wrappers/order_enforcing.py:51, in OrderEnforcing.render(self, *args, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:66, in _EnvDecorator._deprecate_mode.<locals>.render(self, *args, **kwargs)
#      56 elif self.spec is not None and "render_mode" not in self.spec.kwargs.keys():  # type: ignore
#      57     deprecation(
#      58         "You are calling render method, "
#      59         "but you didn't specified the argument render_mode at environment initialization. "
#    (...)
#      63         "See here for more information: https://www.gymlibrary.ml/content/api/"
#      64     )
# ---> 66 return render_func(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:431, in Wrapper.render(self, *args, **kwargs)
#     429 def render(self, *args, **kwargs):
#     430     """Renders the environment."""
# --> 431     return self.env.render(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:66, in _EnvDecorator._deprecate_mode.<locals>.render(self, *args, **kwargs)
#      56 elif self.spec is not None and "render_mode" not in self.spec.kwargs.keys():  # type: ignore
#      57     deprecation(
#      58         "You are calling render method, "
#      59         "but you didn't specified the argument render_mode at environment initialization. "
#    (...)
#      63         "See here for more information: https://www.gymlibrary.ml/content/api/"
#      64     )
# ---> 66 return render_func(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/wrappers/env_checker.py:53, in PassiveEnvChecker.render(self, *args, **kwargs)
#      51 if self.checked_render is False:
#      52     self.checked_render = True
# ---> 53     return env_render_passive_checker(self.env, *args, **kwargs)
#      54 else:
#      55     return self.env.render(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:324, in env_render_passive_checker(env, *args, **kwargs)
#     318     else:
#     319         assert env.render_mode is None or env.render_mode in render_modes, (
#     320             "The environment was initialized successfully however with an unsupported render mode. "
#     321             f"Render mode: {env.render_mode}, modes: {render_modes}"
#     322         )
# --> 324 result = env.render(*args, **kwargs)
#     326 # TODO: Check that the result is correct
#     328 return result
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/core.py:66, in _EnvDecorator._deprecate_mode.<locals>.render(self, *args, **kwargs)
#      56 elif self.spec is not None and "render_mode" not in self.spec.kwargs.keys():  # type: ignore
#      57     deprecation(
#      58         "You are calling render method, "
#      59         "but you didn't specified the argument render_mode at environment initialization. "
#    (...)
#      63         "See here for more information: https://www.gymlibrary.ml/content/api/"
#      64     )
# ---> 66 return render_func(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_env.py:198, in BaseMujocoEnv.render(self, mode, width, height, camera_id, camera_name)
#     196 width = width if width is not None else DEFAULT_SIZE
#     197 height = height if height is not None else DEFAULT_SIZE
# --> 198 return self._render(
#     199     mode=mode,
#     200     width=width,
#     201     height=height,
#     202     camera_id=camera_id,
#     203     camera_name=camera_name,
#     204 )
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_env.py:430, in MujocoEnv._render(self, mode, width, height, camera_id, camera_name)
#     423     if camera_id is None:
#     424         camera_id = mujoco.mj_name2id(
#     425             self.model,
#     426             mujoco.mjtObj.mjOBJ_CAMERA,
#     427             camera_name,
#     428         )
# --> 430         self._get_viewer(mode).render(width, height, camera_id=camera_id)
#     432 if mode in {"rgb_array", "single_rgb_array"}:
#     433     data = self._get_viewer(mode).read_pixels(width, height, depth=False)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_env.py:465, in MujocoEnv._get_viewer(self, mode, width, height)
#     457 elif mode in {
#     458     "rgb_array",
#     459     "depth_array",
#     460     "single_rgb_array",
#     461     "single_depth_array",
#     462 }:
#     463     from gym.envs.mujoco import RenderContextOffscreen
# --> 465     self.viewer = RenderContextOffscreen(
#     466         width, height, self.model, self.data
#     467     )
#     469 self.viewer_setup()
#     470 self._viewers[mode] = self.viewer
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_rendering.py:239, in RenderContextOffscreen.__init__(self, width, height, model, data)
#     236 self._get_opengl_backend(width, height)
#     237 self.opengl_context.make_current()
# --> 239 super().__init__(model, data, offscreen=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_rendering.py:55, in RenderContext.__init__(self, model, data, offscreen)
#      53 self.vopt = mujoco.MjvOption()
#      54 self.pert = mujoco.MjvPerturb()
# ---> 55 self.con = mujoco.MjrContext(self.model, mujoco.mjtFontScale.mjFONTSCALE_150)
#      57 self._markers = []
#      58 self._overlays = {}
#
# FatalError: an OpenGL platform library has not been loaded into this process, this most likely means that a valid OpenGL context has not been created before mjr_makeContext was called
