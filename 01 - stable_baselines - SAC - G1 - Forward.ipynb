# %%
import gym
import numpy as np
import torch

from environments import *

from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.cmd_util import make_vec_env
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /home/user/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/cmd_util.py:5: FutureWarning: Module ``common.cmd_util`` has been renamed to ``common.env_util`` and will be removed in the future.
#   warnings.warn(

# %%
env = make_vec_env("G1Dist-v1", 32)
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/gym/core.py:329: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/user/anaconda3/lib/python3.9/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
model = SAC(
    "MlpPolicy", 
    env, 
    verbose=1,
    policy_kwargs=dict(
        net_arch=[512, 512, 512, 512], 
        activation_fn=torch.nn.ELU,
        n_critics=2,
    ),
    learning_rate=1e-4,
    learning_starts=1000,
    tensorboard_log="./logs/sac/"
)
# Out:
# Using cuda device

# %%
model.learn(
    total_timesteps=1e7, 
    log_interval=100,
    tb_log_name='g1-forward-clean',
)
# Out:
# Logging to ./logs/sac/g1-forward-clean_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 136       |
# |    ep_rew_mean     | -1.49e+03 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 1215      |
# |    time_elapsed    | 15        |
# |    total_timesteps | 19232     |
# | train/             |           |
# |    actor_loss      | 11.2      |
# |    critic_loss     | 8.75      |
# |    ent_coef        | 0.95      |
# |    ent_coef_loss   | -0.758    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 569       |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | -1.8e+03 |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 1214     |
# |    time_elapsed    | 32       |
# |    total_timesteps | 38944    |
# | train/             |          |
# |    actor_loss      | 25.6     |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.894    |
# |    ent_coef_loss   | -1.83    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1185     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 212       |
# |    ep_rew_mean     | -1.83e+03 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 1214      |
# |    time_elapsed    | 50        |
# |    total_timesteps | 61824     |
# | train/             |           |
# |    actor_loss      | 44.6      |
# |    critic_loss     | 51        |
# |    ent_coef        | 0.831     |
# |    ent_coef_loss   | -3.07     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1900      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 184       |
# |    ep_rew_mean     | -1.73e+03 |
# | time/              |           |
# |    episodes        | 400       |
# |    fps             | 1215      |
# |    time_elapsed    | 65        |
# |    total_timesteps | 79776     |
# | train/             |           |
# |    actor_loss      | 62.5      |
# |    critic_loss     | 57.9      |
# |    ent_coef        | 0.785     |
# |    ent_coef_loss   | -3.93     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 2461      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 204       |
# |    ep_rew_mean     | -1.99e+03 |
# | time/              |           |
# |    episodes        | 500       |
# |    fps             | 1215      |
# |    time_elapsed    | 81        |
# |    total_timesteps | 99424     |
# | train/             |           |
# |    actor_loss      | 78        |
# |    critic_loss     | 86.7      |
# |    ent_coef        | 0.738     |
# |    ent_coef_loss   | -5.04     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3075      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 177      |
# |    ep_rew_mean     | -1.7e+03 |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 1215     |
# |    time_elapsed    | 96       |
# |    total_timesteps | 116896   |
# | train/             |          |
# |    actor_loss      | 91.1     |
# |    critic_loss     | 91.8     |
# |    ent_coef        | 0.699    |
# |    ent_coef_loss   | -5.78    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3621     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | -1.6e+03 |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 1215     |
# |    time_elapsed    | 109      |
# |    total_timesteps | 132960   |
# | train/             |          |
# |    actor_loss      | 104      |
# |    critic_loss     | 127      |
# |    ent_coef        | 0.665    |
# |    ent_coef_loss   | -6.57    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4123     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 156       |
# |    ep_rew_mean     | -1.47e+03 |
# | time/              |           |
# |    episodes        | 800       |
# |    fps             | 1214      |
# |    time_elapsed    | 122       |
# |    total_timesteps | 148704    |
# | train/             |           |
# |    actor_loss      | 124       |
# |    critic_loss     | 260       |
# |    ent_coef        | 0.634     |
# |    ent_coef_loss   | -7.45     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 4615      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 155       |
# |    ep_rew_mean     | -1.49e+03 |
# | time/              |           |
# |    episodes        | 900       |
# |    fps             | 1212      |
# |    time_elapsed    | 136       |
# |    total_timesteps | 165120    |
# | train/             |           |
# |    actor_loss      | 136       |
# |    critic_loss     | 302       |
# |    ent_coef        | 0.602     |
# |    ent_coef_loss   | -8.15     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5128      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 147       |
# |    ep_rew_mean     | -1.35e+03 |
# | time/              |           |
# |    episodes        | 1000      |
# |    fps             | 1211      |
# |    time_elapsed    | 147       |
# |    total_timesteps | 178208    |
# | train/             |           |
# |    actor_loss      | 151       |
# |    critic_loss     | 196       |
# |    ent_coef        | 0.579     |
# |    ent_coef_loss   | -8.17     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5537      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 141       |
# |    ep_rew_mean     | -1.36e+03 |
# | time/              |           |
# |    episodes        | 1100      |
# |    fps             | 1209      |
# |    time_elapsed    | 159       |
# |    total_timesteps | 193056    |
# | train/             |           |
# |    actor_loss      | 161       |
# |    critic_loss     | 186       |
# |    ent_coef        | 0.554     |
# |    ent_coef_loss   | -8.62     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6001      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 150       |
# |    ep_rew_mean     | -1.42e+03 |
# | time/              |           |
# |    episodes        | 1200      |
# |    fps             | 1206      |
# |    time_elapsed    | 171       |
# |    total_timesteps | 207360    |
# | train/             |           |
# |    actor_loss      | 177       |
# |    critic_loss     | 371       |
# |    ent_coef        | 0.53      |
# |    ent_coef_loss   | -9.77     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6448      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 130       |
# |    ep_rew_mean     | -1.24e+03 |
# | time/              |           |
# |    episodes        | 1300      |
# |    fps             | 1204      |
# |    time_elapsed    | 182       |
# |    total_timesteps | 220384    |
# | train/             |           |
# |    actor_loss      | 179       |
# |    critic_loss     | 245       |
# |    ent_coef        | 0.51      |
# |    ent_coef_loss   | -9.77     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6855      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 138       |
# |    ep_rew_mean     | -1.33e+03 |
# | time/              |           |
# |    episodes        | 1400      |
# |    fps             | 1202      |
# |    time_elapsed    | 194       |
# |    total_timesteps | 233664    |
# | train/             |           |
# |    actor_loss      | 197       |
# |    critic_loss     | 241       |
# |    ent_coef        | 0.489     |
# |    ent_coef_loss   | -11       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7270      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 147       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 1500      |
# |    fps             | 1200      |
# |    time_elapsed    | 208       |
# |    total_timesteps | 250144    |
# | train/             |           |
# |    actor_loss      | 203       |
# |    critic_loss     | 443       |
# |    ent_coef        | 0.466     |
# |    ent_coef_loss   | -11       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7785      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 137       |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 1600      |
# |    fps             | 1198      |
# |    time_elapsed    | 220       |
# |    total_timesteps | 264128    |
# | train/             |           |
# |    actor_loss      | 220       |
# |    critic_loss     | 386       |
# |    ent_coef        | 0.446     |
# |    ent_coef_loss   | -12       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8222      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 142       |
# |    ep_rew_mean     | -1.26e+03 |
# | time/              |           |
# |    episodes        | 1700      |
# |    fps             | 1197      |
# |    time_elapsed    | 231       |
# |    total_timesteps | 276992    |
# | train/             |           |
# |    actor_loss      | 234       |
# |    critic_loss     | 336       |
# |    ent_coef        | 0.429     |
# |    ent_coef_loss   | -12.6     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8624      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -991     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 1196     |
# |    time_elapsed    | 241      |
# |    total_timesteps | 288896   |
# | train/             |          |
# |    actor_loss      | 233      |
# |    critic_loss     | 285      |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | -13.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8996     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 118       |
# |    ep_rew_mean     | -1.01e+03 |
# | time/              |           |
# |    episodes        | 1900      |
# |    fps             | 1195      |
# |    time_elapsed    | 250       |
# |    total_timesteps | 299680    |
# | train/             |           |
# |    actor_loss      | 245       |
# |    critic_loss     | 380       |
# |    ent_coef        | 0.4       |
# |    ent_coef_loss   | -13.3     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9333      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 164       |
# |    ep_rew_mean     | -1.44e+03 |
# | time/              |           |
# |    episodes        | 2000      |
# |    fps             | 1192      |
# |    time_elapsed    | 266       |
# |    total_timesteps | 317952    |
# | train/             |           |
# |    actor_loss      | 266       |
# |    critic_loss     | 613       |
# |    ent_coef        | 0.379     |
# |    ent_coef_loss   | -13.3     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9904      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 128       |
# |    ep_rew_mean     | -1.06e+03 |
# | time/              |           |
# |    episodes        | 2100      |
# |    fps             | 1191      |
# |    time_elapsed    | 276       |
# |    total_timesteps | 330016    |
# | train/             |           |
# |    actor_loss      | 256       |
# |    critic_loss     | 438       |
# |    ent_coef        | 0.365     |
# |    ent_coef_loss   | -13.9     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 10281     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 1190     |
# |    time_elapsed    | 289      |
# |    total_timesteps | 344448   |
# | train/             |          |
# |    actor_loss      | 269      |
# |    critic_loss     | 362      |
# |    ent_coef        | 0.35     |
# |    ent_coef_loss   | -13.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 10732    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -995     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 1190     |
# |    time_elapsed    | 299      |
# |    total_timesteps | 356160   |
# | train/             |          |
# |    actor_loss      | 284      |
# |    critic_loss     | 421      |
# |    ent_coef        | 0.338    |
# |    ent_coef_loss   | -13.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11098    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 146       |
# |    ep_rew_mean     | -1.12e+03 |
# | time/              |           |
# |    episodes        | 2400      |
# |    fps             | 1189      |
# |    time_elapsed    | 312       |
# |    total_timesteps | 371488    |
# | train/             |           |
# |    actor_loss      | 289       |
# |    critic_loss     | 395       |
# |    ent_coef        | 0.324     |
# |    ent_coef_loss   | -12.3     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 11577     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 170       |
# |    ep_rew_mean     | -1.22e+03 |
# | time/              |           |
# |    episodes        | 2500      |
# |    fps             | 1188      |
# |    time_elapsed    | 327       |
# |    total_timesteps | 388992    |
# | train/             |           |
# |    actor_loss      | 291       |
# |    critic_loss     | 402       |
# |    ent_coef        | 0.308     |
# |    ent_coef_loss   | -12.8     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 12124     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 138       |
# |    ep_rew_mean     | -1.07e+03 |
# | time/              |           |
# |    episodes        | 2600      |
# |    fps             | 1187      |
# |    time_elapsed    | 338       |
# |    total_timesteps | 402208    |
# | train/             |           |
# |    actor_loss      | 285       |
# |    critic_loss     | 358       |
# |    ent_coef        | 0.296     |
# |    ent_coef_loss   | -14.2     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 12537     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 131      |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 1186     |
# |    time_elapsed    | 349      |
# |    total_timesteps | 414656   |
# | train/             |          |
# |    actor_loss      | 299      |
# |    critic_loss     | 471      |
# |    ent_coef        | 0.286    |
# |    ent_coef_loss   | -12.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 12926    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -893     |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 1184     |
# |    time_elapsed    | 360      |
# |    total_timesteps | 427680   |
# | train/             |          |
# |    actor_loss      | 314      |
# |    critic_loss     | 427      |
# |    ent_coef        | 0.276    |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13333    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | -787     |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 1184     |
# |    time_elapsed    | 370      |
# |    total_timesteps | 439520   |
# | train/             |          |
# |    actor_loss      | 314      |
# |    critic_loss     | 471      |
# |    ent_coef        | 0.267    |
# |    ent_coef_loss   | -12      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -949     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 1184     |
# |    time_elapsed    | 383      |
# |    total_timesteps | 454048   |
# | train/             |          |
# |    actor_loss      | 323      |
# |    critic_loss     | 471      |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | -11.3    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14157    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -756     |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 1183     |
# |    time_elapsed    | 392      |
# |    total_timesteps | 464160   |
# | train/             |          |
# |    actor_loss      | 320      |
# |    critic_loss     | 473      |
# |    ent_coef        | 0.25     |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14473    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -781     |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 1182     |
# |    time_elapsed    | 401      |
# |    total_timesteps | 474976   |
# | train/             |          |
# |    actor_loss      | 312      |
# |    critic_loss     | 587      |
# |    ent_coef        | 0.243    |
# |    ent_coef_loss   | -11.7    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14811    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -699     |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 1181     |
# |    time_elapsed    | 410      |
# |    total_timesteps | 485088   |
# | train/             |          |
# |    actor_loss      | 359      |
# |    critic_loss     | 489      |
# |    ent_coef        | 0.237    |
# |    ent_coef_loss   | -10.5    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15127    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.4     |
# |    ep_rew_mean     | -646     |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 1181     |
# |    time_elapsed    | 418      |
# |    total_timesteps | 493984   |
# | train/             |          |
# |    actor_loss      | 326      |
# |    critic_loss     | 487      |
# |    ent_coef        | 0.232    |
# |    ent_coef_loss   | -9.66    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15405    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.2     |
# |    ep_rew_mean     | -693     |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 1180     |
# |    time_elapsed    | 426      |
# |    total_timesteps | 503168   |
# | train/             |          |
# |    actor_loss      | 340      |
# |    critic_loss     | 506      |
# |    ent_coef        | 0.227    |
# |    ent_coef_loss   | -7.58    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15692    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97       |
# |    ep_rew_mean     | -698     |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 1179     |
# |    time_elapsed    | 434      |
# |    total_timesteps | 513024   |
# | train/             |          |
# |    actor_loss      | 341      |
# |    critic_loss     | 641      |
# |    ent_coef        | 0.221    |
# |    ent_coef_loss   | -8.32    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81       |
# |    ep_rew_mean     | -646     |
# | time/              |          |
# |    episodes        | 3700     |
# |    fps             | 1178     |
# |    time_elapsed    | 441      |
# |    total_timesteps | 520672   |
# | train/             |          |
# |    actor_loss      | 341      |
# |    critic_loss     | 520      |
# |    ent_coef        | 0.217    |
# |    ent_coef_loss   | -9.65    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16239    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.4     |
# |    ep_rew_mean     | -636     |
# | time/              |          |
# |    episodes        | 3800     |
# |    fps             | 1177     |
# |    time_elapsed    | 449      |
# |    total_timesteps | 529760   |
# | train/             |          |
# |    actor_loss      | 351      |
# |    critic_loss     | 562      |
# |    ent_coef        | 0.212    |
# |    ent_coef_loss   | -7.77    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16523    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.1     |
# |    ep_rew_mean     | -559     |
# | time/              |          |
# |    episodes        | 3900     |
# |    fps             | 1175     |
# |    time_elapsed    | 457      |
# |    total_timesteps | 538048   |
# | train/             |          |
# |    actor_loss      | 353      |
# |    critic_loss     | 696      |
# |    ent_coef        | 0.208    |
# |    ent_coef_loss   | -7.7     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16782    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.7     |
# |    ep_rew_mean     | -582     |
# | time/              |          |
# |    episodes        | 4000     |
# |    fps             | 1174     |
# |    time_elapsed    | 465      |
# |    total_timesteps | 546336   |
# | train/             |          |
# |    actor_loss      | 342      |
# |    critic_loss     | 1.07e+03 |
# |    ent_coef        | 0.203    |
# |    ent_coef_loss   | -7.83    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17041    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.8     |
# |    ep_rew_mean     | -600     |
# | time/              |          |
# |    episodes        | 4100     |
# |    fps             | 1173     |
# |    time_elapsed    | 472      |
# |    total_timesteps | 554016   |
# | train/             |          |
# |    actor_loss      | 336      |
# |    critic_loss     | 626      |
# |    ent_coef        | 0.2      |
# |    ent_coef_loss   | -7.93    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17281    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62       |
# |    ep_rew_mean     | -452     |
# | time/              |          |
# |    episodes        | 4200     |
# |    fps             | 1172     |
# |    time_elapsed    | 478      |
# |    total_timesteps | 560448   |
# | train/             |          |
# |    actor_loss      | 346      |
# |    critic_loss     | 662      |
# |    ent_coef        | 0.197    |
# |    ent_coef_loss   | -8.18    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17482    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.6     |
# |    ep_rew_mean     | -482     |
# | time/              |          |
# |    episodes        | 4300     |
# |    fps             | 1171     |
# |    time_elapsed    | 482      |
# |    total_timesteps | 565920   |
# | train/             |          |
# |    actor_loss      | 360      |
# |    critic_loss     | 660      |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -5.95    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17653    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62.4     |
# |    ep_rew_mean     | -474     |
# | time/              |          |
# |    episodes        | 4400     |
# |    fps             | 1171     |
# |    time_elapsed    | 488      |
# |    total_timesteps | 572352   |
# | train/             |          |
# |    actor_loss      | 373      |
# |    critic_loss     | 595      |
# |    ent_coef        | 0.191    |
# |    ent_coef_loss   | -8.34    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17854    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.7     |
# |    ep_rew_mean     | -493     |
# | time/              |          |
# |    episodes        | 4500     |
# |    fps             | 1170     |
# |    time_elapsed    | 494      |
# |    total_timesteps | 578816   |
# | train/             |          |
# |    actor_loss      | 329      |
# |    critic_loss     | 648      |
# |    ent_coef        | 0.189    |
# |    ent_coef_loss   | -5.28    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18056    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.8     |
# |    ep_rew_mean     | -441     |
# | time/              |          |
# |    episodes        | 4600     |
# |    fps             | 1170     |
# |    time_elapsed    | 499      |
# |    total_timesteps | 584512   |
# | train/             |          |
# |    actor_loss      | 335      |
# |    critic_loss     | 553      |
# |    ent_coef        | 0.186    |
# |    ent_coef_loss   | -6.03    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18234    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.9     |
# |    ep_rew_mean     | -551     |
# | time/              |          |
# |    episodes        | 4700     |
# |    fps             | 1170     |
# |    time_elapsed    | 504      |
# |    total_timesteps | 590528   |
# | train/             |          |
# |    actor_loss      | 327      |
# |    critic_loss     | 680      |
# |    ent_coef        | 0.183    |
# |    ent_coef_loss   | -4.35    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18422    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.9     |
# |    ep_rew_mean     | -440     |
# | time/              |          |
# |    episodes        | 4800     |
# |    fps             | 1169     |
# |    time_elapsed    | 509      |
# |    total_timesteps | 595776   |
# | train/             |          |
# |    actor_loss      | 353      |
# |    critic_loss     | 588      |
# |    ent_coef        | 0.182    |
# |    ent_coef_loss   | -4.26    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18586    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.8     |
# |    ep_rew_mean     | -452     |
# | time/              |          |
# |    episodes        | 4900     |
# |    fps             | 1168     |
# |    time_elapsed    | 514      |
# |    total_timesteps | 601408   |
# | train/             |          |
# |    actor_loss      | 365      |
# |    critic_loss     | 824      |
# |    ent_coef        | 0.18     |
# |    ent_coef_loss   | -1.54    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18762    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.9     |
# |    ep_rew_mean     | -392     |
# | time/              |          |
# |    episodes        | 5000     |
# |    fps             | 1168     |
# |    time_elapsed    | 519      |
# |    total_timesteps | 606528   |
# | train/             |          |
# |    actor_loss      | 338      |
# |    critic_loss     | 723      |
# |    ent_coef        | 0.178    |
# |    ent_coef_loss   | -5.88    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18922    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.3     |
# |    ep_rew_mean     | -447     |
# | time/              |          |
# |    episodes        | 5100     |
# |    fps             | 1168     |
# |    time_elapsed    | 523      |
# |    total_timesteps | 611680   |
# | train/             |          |
# |    actor_loss      | 352      |
# |    critic_loss     | 635      |
# |    ent_coef        | 0.176    |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19083    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.9     |
# |    ep_rew_mean     | -474     |
# | time/              |          |
# |    episodes        | 5200     |
# |    fps             | 1168     |
# |    time_elapsed    | 527      |
# |    total_timesteps | 616736   |
# | train/             |          |
# |    actor_loss      | 337      |
# |    critic_loss     | 861      |
# |    ent_coef        | 0.175    |
# |    ent_coef_loss   | -3.96    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19241    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -423     |
# | time/              |          |
# |    episodes        | 5300     |
# |    fps             | 1167     |
# |    time_elapsed    | 532      |
# |    total_timesteps | 621504   |
# | train/             |          |
# |    actor_loss      | 328      |
# |    critic_loss     | 740      |
# |    ent_coef        | 0.174    |
# |    ent_coef_loss   | -4.53    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19390    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.8     |
# |    ep_rew_mean     | -508     |
# | time/              |          |
# |    episodes        | 5400     |
# |    fps             | 1167     |
# |    time_elapsed    | 537      |
# |    total_timesteps | 627104   |
# | train/             |          |
# |    actor_loss      | 331      |
# |    critic_loss     | 659      |
# |    ent_coef        | 0.172    |
# |    ent_coef_loss   | -3.23    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19565    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.6     |
# |    ep_rew_mean     | -523     |
# | time/              |          |
# |    episodes        | 5500     |
# |    fps             | 1167     |
# |    time_elapsed    | 542      |
# |    total_timesteps | 632640   |
# | train/             |          |
# |    actor_loss      | 361      |
# |    critic_loss     | 734      |
# |    ent_coef        | 0.17     |
# |    ent_coef_loss   | -4.45    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19738    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | -417     |
# | time/              |          |
# |    episodes        | 5600     |
# |    fps             | 1166     |
# |    time_elapsed    | 546      |
# |    total_timesteps | 637696   |
# | train/             |          |
# |    actor_loss      | 352      |
# |    critic_loss     | 857      |
# |    ent_coef        | 0.168    |
# |    ent_coef_loss   | -1.89    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19896    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.7     |
# |    ep_rew_mean     | -442     |
# | time/              |          |
# |    episodes        | 5700     |
# |    fps             | 1165     |
# |    time_elapsed    | 551      |
# |    total_timesteps | 642464   |
# | train/             |          |
# |    actor_loss      | 345      |
# |    critic_loss     | 762      |
# |    ent_coef        | 0.167    |
# |    ent_coef_loss   | -1.25    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20045    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.4     |
# |    ep_rew_mean     | -407     |
# | time/              |          |
# |    episodes        | 5800     |
# |    fps             | 1165     |
# |    time_elapsed    | 555      |
# |    total_timesteps | 647008   |
# | train/             |          |
# |    actor_loss      | 332      |
# |    critic_loss     | 1.16e+03 |
# |    ent_coef        | 0.166    |
# |    ent_coef_loss   | -4.62    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20187    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.7     |
# |    ep_rew_mean     | -459     |
# | time/              |          |
# |    episodes        | 5900     |
# |    fps             | 1164     |
# |    time_elapsed    | 560      |
# |    total_timesteps | 652960   |
# | train/             |          |
# |    actor_loss      | 313      |
# |    critic_loss     | 593      |
# |    ent_coef        | 0.164    |
# |    ent_coef_loss   | -3.73    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.8     |
# |    ep_rew_mean     | -449     |
# | time/              |          |
# |    episodes        | 6000     |
# |    fps             | 1164     |
# |    time_elapsed    | 565      |
# |    total_timesteps | 657920   |
# | train/             |          |
# |    actor_loss      | 338      |
# |    critic_loss     | 634      |
# |    ent_coef        | 0.163    |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20528    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.9     |
# |    ep_rew_mean     | -482     |
# | time/              |          |
# |    episodes        | 6100     |
# |    fps             | 1163     |
# |    time_elapsed    | 570      |
# |    total_timesteps | 663712   |
# | train/             |          |
# |    actor_loss      | 335      |
# |    critic_loss     | 633      |
# |    ent_coef        | 0.161    |
# |    ent_coef_loss   | -2.58    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20709    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.3     |
# |    ep_rew_mean     | -459     |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 1162     |
# |    time_elapsed    | 574      |
# |    total_timesteps | 668480   |
# | train/             |          |
# |    actor_loss      | 344      |
# |    critic_loss     | 661      |
# |    ent_coef        | 0.16     |
# |    ent_coef_loss   | 0.493    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20858    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.9     |
# |    ep_rew_mean     | -522     |
# | time/              |          |
# |    episodes        | 6300     |
# |    fps             | 1162     |
# |    time_elapsed    | 580      |
# |    total_timesteps | 674240   |
# | train/             |          |
# |    actor_loss      | 343      |
# |    critic_loss     | 907      |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -2.03    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21038    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 68.8     |
# |    ep_rew_mean     | -536     |
# | time/              |          |
# |    episodes        | 6400     |
# |    fps             | 1161     |
# |    time_elapsed    | 586      |
# |    total_timesteps | 681216   |
# | train/             |          |
# |    actor_loss      | 316      |
# |    critic_loss     | 1.08e+03 |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21256    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.1     |
# |    ep_rew_mean     | -593     |
# | time/              |          |
# |    episodes        | 6500     |
# |    fps             | 1159     |
# |    time_elapsed    | 593      |
# |    total_timesteps | 688672   |
# | train/             |          |
# |    actor_loss      | 306      |
# |    critic_loss     | 585      |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21489    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.8     |
# |    ep_rew_mean     | -620     |
# | time/              |          |
# |    episodes        | 6600     |
# |    fps             | 1158     |
# |    time_elapsed    | 601      |
# |    total_timesteps | 696576   |
# | train/             |          |
# |    actor_loss      | 312      |
# |    critic_loss     | 591      |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -0.939   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21736    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71       |
# |    ep_rew_mean     | -547     |
# | time/              |          |
# |    episodes        | 6700     |
# |    fps             | 1156     |
# |    time_elapsed    | 607      |
# |    total_timesteps | 703264   |
# | train/             |          |
# |    actor_loss      | 322      |
# |    critic_loss     | 676      |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21945    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.6     |
# |    ep_rew_mean     | -602     |
# | time/              |          |
# |    episodes        | 6800     |
# |    fps             | 1155     |
# |    time_elapsed    | 614      |
# |    total_timesteps | 709984   |
# | train/             |          |
# |    actor_loss      | 314      |
# |    critic_loss     | 846      |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -0.863   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22155    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57       |
# |    ep_rew_mean     | -530     |
# | time/              |          |
# |    episodes        | 6900     |
# |    fps             | 1154     |
# |    time_elapsed    | 620      |
# |    total_timesteps | 716064   |
# | train/             |          |
# |    actor_loss      | 295      |
# |    critic_loss     | 639      |
# |    ent_coef        | 0.158    |
# |    ent_coef_loss   | 0.401    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22345    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.3     |
# |    ep_rew_mean     | -516     |
# | time/              |          |
# |    episodes        | 7000     |
# |    fps             | 1154     |
# |    time_elapsed    | 625      |
# |    total_timesteps | 722176   |
# | train/             |          |
# |    actor_loss      | 309      |
# |    critic_loss     | 698      |
# |    ent_coef        | 0.158    |
# |    ent_coef_loss   | 0.33     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22536    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58.6     |
# |    ep_rew_mean     | -480     |
# | time/              |          |
# |    episodes        | 7100     |
# |    fps             | 1153     |
# |    time_elapsed    | 631      |
# |    total_timesteps | 728064   |
# | train/             |          |
# |    actor_loss      | 279      |
# |    critic_loss     | 946      |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -0.565   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22720    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.6     |
# |    ep_rew_mean     | -489     |
# | time/              |          |
# |    episodes        | 7200     |
# |    fps             | 1152     |
# |    time_elapsed    | 636      |
# |    total_timesteps | 733824   |
# | train/             |          |
# |    actor_loss      | 302      |
# |    critic_loss     | 659      |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | 0.274    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22900    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.4     |
# |    ep_rew_mean     | -434     |
# | time/              |          |
# |    episodes        | 7300     |
# |    fps             | 1152     |
# |    time_elapsed    | 641      |
# |    total_timesteps | 739584   |
# | train/             |          |
# |    actor_loss      | 295      |
# |    critic_loss     | 597      |
# |    ent_coef        | 0.162    |
# |    ent_coef_loss   | 2.52     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23080    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.6     |
# |    ep_rew_mean     | -439     |
# | time/              |          |
# |    episodes        | 7400     |
# |    fps             | 1151     |
# |    time_elapsed    | 646      |
# |    total_timesteps | 745152   |
# | train/             |          |
# |    actor_loss      | 296      |
# |    critic_loss     | 894      |
# |    ent_coef        | 0.162    |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23254    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.8     |
# |    ep_rew_mean     | -461     |
# | time/              |          |
# |    episodes        | 7500     |
# |    fps             | 1151     |
# |    time_elapsed    | 652      |
# |    total_timesteps | 750816   |
# | train/             |          |
# |    actor_loss      | 286      |
# |    critic_loss     | 602      |
# |    ent_coef        | 0.164    |
# |    ent_coef_loss   | 0.57     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23431    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58.9     |
# |    ep_rew_mean     | -544     |
# | time/              |          |
# |    episodes        | 7600     |
# |    fps             | 1151     |
# |    time_elapsed    | 657      |
# |    total_timesteps | 756800   |
# | train/             |          |
# |    actor_loss      | 288      |
# |    critic_loss     | 645      |
# |    ent_coef        | 0.164    |
# |    ent_coef_loss   | 0.823    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23618    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.9     |
# |    ep_rew_mean     | -478     |
# | time/              |          |
# |    episodes        | 7700     |
# |    fps             | 1150     |
# |    time_elapsed    | 662      |
# |    total_timesteps | 762560   |
# | train/             |          |
# |    actor_loss      | 271      |
# |    critic_loss     | 824      |
# |    ent_coef        | 0.165    |
# |    ent_coef_loss   | -0.298   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23798    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -420     |
# | time/              |          |
# |    episodes        | 7800     |
# |    fps             | 1150     |
# |    time_elapsed    | 667      |
# |    total_timesteps | 767552   |
# | train/             |          |
# |    actor_loss      | 290      |
# |    critic_loss     | 605      |
# |    ent_coef        | 0.165    |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23954    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.8     |
# |    ep_rew_mean     | -501     |
# | time/              |          |
# |    episodes        | 7900     |
# |    fps             | 1150     |
# |    time_elapsed    | 671      |
# |    total_timesteps | 772992   |
# | train/             |          |
# |    actor_loss      | 286      |
# |    critic_loss     | 590      |
# |    ent_coef        | 0.164    |
# |    ent_coef_loss   | 2.01     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24124    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.1     |
# |    ep_rew_mean     | -443     |
# | time/              |          |
# |    episodes        | 8000     |
# |    fps             | 1150     |
# |    time_elapsed    | 676      |
# |    total_timesteps | 778016   |
# | train/             |          |
# |    actor_loss      | 282      |
# |    critic_loss     | 648      |
# |    ent_coef        | 0.165    |
# |    ent_coef_loss   | -0.627   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24281    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.5     |
# |    ep_rew_mean     | -459     |
# | time/              |          |
# |    episodes        | 8100     |
# |    fps             | 1150     |
# |    time_elapsed    | 680      |
# |    total_timesteps | 782432   |
# | train/             |          |
# |    actor_loss      | 302      |
# |    critic_loss     | 705      |
# |    ent_coef        | 0.166    |
# |    ent_coef_loss   | 2.41     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24419    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.3     |
# |    ep_rew_mean     | -487     |
# | time/              |          |
# |    episodes        | 8200     |
# |    fps             | 1150     |
# |    time_elapsed    | 684      |
# |    total_timesteps | 787360   |
# | train/             |          |
# |    actor_loss      | 285      |
# |    critic_loss     | 751      |
# |    ent_coef        | 0.168    |
# |    ent_coef_loss   | 2.85     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24573    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54       |
# |    ep_rew_mean     | -516     |
# | time/              |          |
# |    episodes        | 8300     |
# ...
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 467       |
# |    ep_rew_mean     | 1.03e+04  |
# | time/              |           |
# |    episodes        | 124800    |
# |    fps             | 1156      |
# |    time_elapsed    | 7557      |
# |    total_timesteps | 8740160   |
# | train/             |           |
# |    actor_loss      | -2.04e+03 |
# |    critic_loss     | 861       |
# |    ent_coef        | 0.228     |
# |    ent_coef_loss   | 0.625     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 273098    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 490       |
# |    ep_rew_mean     | 1.18e+04  |
# | time/              |           |
# |    episodes        | 124900    |
# |    fps             | 1156      |
# |    time_elapsed    | 7600      |
# |    total_timesteps | 8789024   |
# | train/             |           |
# |    actor_loss      | -2.08e+03 |
# |    critic_loss     | 1.98e+04  |
# |    ent_coef        | 0.217     |
# |    ent_coef_loss   | -1.24     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 274625    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 478      |
# |    ep_rew_mean     | 1.11e+04 |
# | time/              |          |
# |    episodes        | 125000   |
# |    fps             | 1156     |
# |    time_elapsed    | 7642     |
# |    total_timesteps | 8837088  |
# | train/             |          |
# |    actor_loss      | -2.1e+03 |
# |    critic_loss     | 315      |
# |    ent_coef        | 0.225    |
# |    ent_coef_loss   | -0.667   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 276127   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 496       |
# |    ep_rew_mean     | 1.25e+04  |
# | time/              |           |
# |    episodes        | 125100    |
# |    fps             | 1156      |
# |    time_elapsed    | 7685      |
# |    total_timesteps | 8886624   |
# | train/             |           |
# |    actor_loss      | -2.05e+03 |
# |    critic_loss     | 813       |
# |    ent_coef        | 0.243     |
# |    ent_coef_loss   | 0.0623    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 277675    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 502       |
# |    ep_rew_mean     | 1.3e+04   |
# | time/              |           |
# |    episodes        | 125200    |
# |    fps             | 1156      |
# |    time_elapsed    | 7729      |
# |    total_timesteps | 8935680   |
# | train/             |           |
# |    actor_loss      | -2.03e+03 |
# |    critic_loss     | 483       |
# |    ent_coef        | 0.225     |
# |    ent_coef_loss   | 1.3       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 279208    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 502       |
# |    ep_rew_mean     | 1.3e+04   |
# | time/              |           |
# |    episodes        | 125300    |
# |    fps             | 1156      |
# |    time_elapsed    | 7773      |
# |    total_timesteps | 8986912   |
# | train/             |           |
# |    actor_loss      | -2.03e+03 |
# |    critic_loss     | 381       |
# |    ent_coef        | 0.217     |
# |    ent_coef_loss   | 1.1       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 280809    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 496       |
# |    ep_rew_mean     | 1.28e+04  |
# | time/              |           |
# |    episodes        | 125400    |
# |    fps             | 1155      |
# |    time_elapsed    | 7817      |
# |    total_timesteps | 9036640   |
# | train/             |           |
# |    actor_loss      | -2.08e+03 |
# |    critic_loss     | 1.2e+03   |
# |    ent_coef        | 0.216     |
# |    ent_coef_loss   | 0.439     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 282363    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 491      |
# |    ep_rew_mean     | 1.22e+04 |
# | time/              |          |
# |    episodes        | 125500   |
# |    fps             | 1155     |
# |    time_elapsed    | 7862     |
# |    total_timesteps | 9087136  |
# | train/             |          |
# |    actor_loss      | -2.1e+03 |
# |    critic_loss     | 1.65e+03 |
# |    ent_coef        | 0.229    |
# |    ent_coef_loss   | 0.302    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 283941   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 484       |
# |    ep_rew_mean     | 1.19e+04  |
# | time/              |           |
# |    episodes        | 125600    |
# |    fps             | 1155      |
# |    time_elapsed    | 7903      |
# |    total_timesteps | 9134112   |
# | train/             |           |
# |    actor_loss      | -2.12e+03 |
# |    critic_loss     | 1.83e+04  |
# |    ent_coef        | 0.237     |
# |    ent_coef_loss   | -0.35     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 285409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 480       |
# |    ep_rew_mean     | 1.09e+04  |
# | time/              |           |
# |    episodes        | 125700    |
# |    fps             | 1155      |
# |    time_elapsed    | 7947      |
# |    total_timesteps | 9183200   |
# | train/             |           |
# |    actor_loss      | -2.11e+03 |
# |    critic_loss     | 855       |
# |    ent_coef        | 0.255     |
# |    ent_coef_loss   | -0.195    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 286943    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 469       |
# |    ep_rew_mean     | 1.19e+04  |
# | time/              |           |
# |    episodes        | 125800    |
# |    fps             | 1155      |
# |    time_elapsed    | 7987      |
# |    total_timesteps | 9229472   |
# | train/             |           |
# |    actor_loss      | -2.17e+03 |
# |    critic_loss     | 2.18e+04  |
# |    ent_coef        | 0.257     |
# |    ent_coef_loss   | -0.222    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 288389    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 462       |
# |    ep_rew_mean     | 9.41e+03  |
# | time/              |           |
# |    episodes        | 125900    |
# |    fps             | 1155      |
# |    time_elapsed    | 8028      |
# |    total_timesteps | 9274816   |
# | train/             |           |
# |    actor_loss      | -2.07e+03 |
# |    critic_loss     | 2.03e+04  |
# |    ent_coef        | 0.267     |
# |    ent_coef_loss   | -0.0131   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 289806    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 482      |
# |    ep_rew_mean     | 1.17e+04 |
# | time/              |          |
# |    episodes        | 126000   |
# |    fps             | 1155     |
# |    time_elapsed    | 8070     |
# |    total_timesteps | 9323008  |
# | train/             |          |
# |    actor_loss      | -2.1e+03 |
# |    critic_loss     | 2.11e+04 |
# |    ent_coef        | 0.273    |
# |    ent_coef_loss   | -0.935   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 291312   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 500       |
# |    ep_rew_mean     | 1.26e+04  |
# | time/              |           |
# |    episodes        | 126100    |
# |    fps             | 1155      |
# |    time_elapsed    | 8115      |
# |    total_timesteps | 9373536   |
# | train/             |           |
# |    actor_loss      | -2.11e+03 |
# |    critic_loss     | 1.99e+04  |
# |    ent_coef        | 0.282     |
# |    ent_coef_loss   | -1.32     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 292891    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 488       |
# |    ep_rew_mean     | 1.12e+04  |
# | time/              |           |
# |    episodes        | 126200    |
# |    fps             | 1155      |
# |    time_elapsed    | 8156      |
# |    total_timesteps | 9421760   |
# | train/             |           |
# |    actor_loss      | -2.16e+03 |
# |    critic_loss     | 263       |
# |    ent_coef        | 0.272     |
# |    ent_coef_loss   | -1.01     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 294398    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 471       |
# |    ep_rew_mean     | 1.21e+04  |
# | time/              |           |
# |    episodes        | 126300    |
# |    fps             | 1155      |
# |    time_elapsed    | 8198      |
# |    total_timesteps | 9469856   |
# | train/             |           |
# |    actor_loss      | -2.13e+03 |
# |    critic_loss     | 513       |
# |    ent_coef        | 0.272     |
# |    ent_coef_loss   | 0.209     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 295901    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 473       |
# |    ep_rew_mean     | 1.24e+04  |
# | time/              |           |
# |    episodes        | 126400    |
# |    fps             | 1154      |
# |    time_elapsed    | 8239      |
# |    total_timesteps | 9516512   |
# | train/             |           |
# |    actor_loss      | -2.07e+03 |
# |    critic_loss     | 2.22e+04  |
# |    ent_coef        | 0.287     |
# |    ent_coef_loss   | 1.16      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 297359    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 484       |
# |    ep_rew_mean     | 1.25e+04  |
# | time/              |           |
# |    episodes        | 126500    |
# |    fps             | 1154      |
# |    time_elapsed    | 8282      |
# |    total_timesteps | 9565088   |
# | train/             |           |
# |    actor_loss      | -2.16e+03 |
# |    critic_loss     | 1.87e+04  |
# |    ent_coef        | 0.26      |
# |    ent_coef_loss   | -2.29     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 298877    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 363       |
# |    ep_rew_mean     | 9.18e+03  |
# | time/              |           |
# |    episodes        | 126600    |
# |    fps             | 1154      |
# |    time_elapsed    | 8313      |
# |    total_timesteps | 9600384   |
# | train/             |           |
# |    actor_loss      | -2.18e+03 |
# |    critic_loss     | 2.3e+04   |
# |    ent_coef        | 0.253     |
# |    ent_coef_loss   | 0.236     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 299980    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 483       |
# |    ep_rew_mean     | 1.21e+04  |
# | time/              |           |
# |    episodes        | 126700    |
# |    fps             | 1154      |
# |    time_elapsed    | 8355      |
# |    total_timesteps | 9648576   |
# | train/             |           |
# |    actor_loss      | -2.15e+03 |
# |    critic_loss     | 6.65e+03  |
# |    ent_coef        | 0.261     |
# |    ent_coef_loss   | 0.263     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 301486    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 458       |
# |    ep_rew_mean     | 1.11e+04  |
# | time/              |           |
# |    episodes        | 126800    |
# |    fps             | 1154      |
# |    time_elapsed    | 8397      |
# |    total_timesteps | 9696480   |
# | train/             |           |
# |    actor_loss      | -2.15e+03 |
# |    critic_loss     | 413       |
# |    ent_coef        | 0.265     |
# |    ent_coef_loss   | 0.741     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 302983    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 483       |
# |    ep_rew_mean     | 1.16e+04  |
# | time/              |           |
# |    episodes        | 126900    |
# |    fps             | 1154      |
# |    time_elapsed    | 8437      |
# |    total_timesteps | 9744672   |
# | train/             |           |
# |    actor_loss      | -2.18e+03 |
# |    critic_loss     | 461       |
# |    ent_coef        | 0.25      |
# |    ent_coef_loss   | 0.332     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 304489    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 500       |
# |    ep_rew_mean     | 1.28e+04  |
# | time/              |           |
# |    episodes        | 127000    |
# |    fps             | 1154      |
# |    time_elapsed    | 8480      |
# |    total_timesteps | 9793760   |
# | train/             |           |
# |    actor_loss      | -2.18e+03 |
# |    critic_loss     | 339       |
# |    ent_coef        | 0.247     |
# |    ent_coef_loss   | -0.261    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 306023    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 493      |
# |    ep_rew_mean     | 1.28e+04 |
# | time/              |          |
# |    episodes        | 127100   |
# |    fps             | 1154     |
# |    time_elapsed    | 8523     |
# |    total_timesteps | 9842656  |
# | train/             |          |
# |    actor_loss      | -2.2e+03 |
# |    critic_loss     | 2.27e+04 |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | 0.481    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 307551   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 493       |
# |    ep_rew_mean     | 1.27e+04  |
# | time/              |           |
# |    episodes        | 127200    |
# |    fps             | 1154      |
# |    time_elapsed    | 8566      |
# |    total_timesteps | 9891776   |
# | train/             |           |
# |    actor_loss      | -2.16e+03 |
# |    critic_loss     | 478       |
# |    ent_coef        | 0.262     |
# |    ent_coef_loss   | 0.482     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 309086    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 482       |
# |    ep_rew_mean     | 1.21e+04  |
# | time/              |           |
# |    episodes        | 127300    |
# |    fps             | 1154      |
# |    time_elapsed    | 8608      |
# |    total_timesteps | 9939968   |
# | train/             |           |
# |    actor_loss      | -2.15e+03 |
# |    critic_loss     | 390       |
# |    ent_coef        | 0.249     |
# |    ent_coef_loss   | -0.145    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 310592    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 500       |
# |    ep_rew_mean     | 1.34e+04  |
# | time/              |           |
# |    episodes        | 127400    |
# |    fps             | 1154      |
# |    time_elapsed    | 8652      |
# |    total_timesteps | 9989504   |
# | train/             |           |
# |    actor_loss      | -2.17e+03 |
# |    critic_loss     | 1.41e+03  |
# |    ent_coef        | 0.25      |
# |    ent_coef_loss   | 0.901     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 312140    |
# ----------------------------------

# %%
model.save("trained_models/g1-forward/sac-clean")
