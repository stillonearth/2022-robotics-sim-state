# %%
import gym
import numpy as np
import torch

from environments import *

from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.cmd_util import make_vec_env
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /home/user/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/cmd_util.py:5: FutureWarning: Module ``common.cmd_util`` has been renamed to ``common.env_util`` and will be removed in the future.
#   warnings.warn(

# %%
env = make_vec_env("G1Dist-v1", 16)
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/gym/core.py:329: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/user/anaconda3/lib/python3.9/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
model = SAC(
    "MlpPolicy", 
    env, 
    verbose=1,
    policy_kwargs=dict(
        net_arch=[512, 512, 512, 512], 
        activation_fn=torch.nn.ELU,
        n_critics=5,
    ),
    learning_rate=1e-4,
    learning_starts=1000,
    tensorboard_log="./logs/sac/"
)
# Out:
# Using cuda device

# %%
model.set_parameters("trained_models/g1-forward/sac")

# %%
model.learn(
    total_timesteps=5e7, 
    log_interval=100,
)
# Out:
# Logging to ./logs/sac/SAC_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.7     |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 558      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 8672     |
# | train/             |          |
# |    actor_loss      | -46.7    |
# |    critic_loss     | 351      |
# |    ent_coef        | 0.884    |
# |    ent_coef_loss   | -1.53    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 479      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.8     |
# |    ep_rew_mean     | 193      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 529      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 16816    |
# | train/             |          |
# |    actor_loss      | -59.8    |
# |    critic_loss     | 313      |
# |    ent_coef        | 0.824    |
# |    ent_coef_loss   | -2.3     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 988      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | 215      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 520      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 24848    |
# | train/             |          |
# |    actor_loss      | -75      |
# |    critic_loss     | 361      |
# |    ent_coef        | 0.776    |
# |    ent_coef_loss   | -3.2     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1490     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.3     |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 515      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 32592    |
# | train/             |          |
# |    actor_loss      | -78.1    |
# |    critic_loss     | 376      |
# |    ent_coef        | 0.735    |
# |    ent_coef_loss   | -3.82    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1974     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.5     |
# |    ep_rew_mean     | 240      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 513      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 40256    |
# | train/             |          |
# |    actor_loss      | -83.3    |
# |    critic_loss     | 338      |
# |    ent_coef        | 0.699    |
# |    ent_coef_loss   | -4.22    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2453     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78       |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 511      |
# |    time_elapsed    | 94       |
# |    total_timesteps | 48192    |
# | train/             |          |
# |    actor_loss      | -94.6    |
# |    critic_loss     | 278      |
# |    ent_coef        | 0.665    |
# |    ent_coef_loss   | -4.84    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2949     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.3     |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 515      |
# |    time_elapsed    | 107      |
# |    total_timesteps | 55504    |
# | train/             |          |
# |    actor_loss      | -80.5    |
# |    critic_loss     | 349      |
# |    ent_coef        | 0.636    |
# |    ent_coef_loss   | -5.32    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3406     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74       |
# |    ep_rew_mean     | 317      |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 515      |
# |    time_elapsed    | 121      |
# |    total_timesteps | 62864    |
# | train/             |          |
# |    actor_loss      | -97.2    |
# |    critic_loss     | 281      |
# |    ent_coef        | 0.609    |
# |    ent_coef_loss   | -5.31    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3866     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.8     |
# |    ep_rew_mean     | 341      |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 514      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 70352    |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 251      |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | -5.57    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4334     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.5     |
# |    ep_rew_mean     | 349      |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 513      |
# |    time_elapsed    | 151      |
# |    total_timesteps | 77680    |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 256      |
# |    ent_coef        | 0.557    |
# |    ent_coef_loss   | -6.09    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4792     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.7     |
# |    ep_rew_mean     | 348      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 514      |
# |    time_elapsed    | 165      |
# |    total_timesteps | 84992    |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 301      |
# |    ent_coef        | 0.534    |
# |    ent_coef_loss   | -7.01    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5249     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.4     |
# |    ep_rew_mean     | 362      |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 513      |
# |    time_elapsed    | 179      |
# |    total_timesteps | 92048    |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 207      |
# |    ent_coef        | 0.512    |
# |    ent_coef_loss   | -6.68    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5690     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.3     |
# |    ep_rew_mean     | 378      |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 515      |
# |    time_elapsed    | 193      |
# |    total_timesteps | 99616    |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 239      |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | -6.73    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6163     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.1     |
# |    ep_rew_mean     | 368      |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 515      |
# |    time_elapsed    | 207      |
# |    total_timesteps | 106832   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 287      |
# |    ent_coef        | 0.469    |
# |    ent_coef_loss   | -6.94    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6614     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.7     |
# |    ep_rew_mean     | 378      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 517      |
# |    time_elapsed    | 220      |
# |    total_timesteps | 114080   |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 240      |
# |    ent_coef        | 0.449    |
# |    ent_coef_loss   | -7.22    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7067     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.4     |
# |    ep_rew_mean     | 382      |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 519      |
# |    time_elapsed    | 233      |
# |    total_timesteps | 121280   |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 260      |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -7.66    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7517     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.7     |
# |    ep_rew_mean     | 412      |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 521      |
# |    time_elapsed    | 246      |
# |    total_timesteps | 128448   |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 226      |
# |    ent_coef        | 0.412    |
# |    ent_coef_loss   | -7.62    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7965     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.9     |
# |    ep_rew_mean     | 419      |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 521      |
# |    time_elapsed    | 260      |
# |    total_timesteps | 135632   |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 211      |
# |    ent_coef        | 0.395    |
# |    ent_coef_loss   | -8.36    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8414     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.1     |
# |    ep_rew_mean     | 423      |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 522      |
# |    time_elapsed    | 273      |
# |    total_timesteps | 143104   |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 223      |
# |    ent_coef        | 0.379    |
# |    ent_coef_loss   | -7.75    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8881     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.7     |
# |    ep_rew_mean     | 433      |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 521      |
# |    time_elapsed    | 287      |
# |    total_timesteps | 150016   |
# | train/             |          |
# |    actor_loss      | -149     |
# |    critic_loss     | 184      |
# |    ent_coef        | 0.364    |
# |    ent_coef_loss   | -8.45    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9313     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.1     |
# |    ep_rew_mean     | 449      |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 520      |
# |    time_elapsed    | 301      |
# |    total_timesteps | 157264   |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 196      |
# |    ent_coef        | 0.349    |
# |    ent_coef_loss   | -7.99    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9766     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.3     |
# |    ep_rew_mean     | 443      |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 520      |
# |    time_elapsed    | 316      |
# |    total_timesteps | 164336   |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 206      |
# |    ent_coef        | 0.335    |
# |    ent_coef_loss   | -7.98    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 10208    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.3     |
# |    ep_rew_mean     | 456      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 519      |
# |    time_elapsed    | 330      |
# |    total_timesteps | 171472   |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 177      |
# |    ent_coef        | 0.322    |
# |    ent_coef_loss   | -8.64    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 10654    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.8     |
# |    ep_rew_mean     | 484      |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 518      |
# |    time_elapsed    | 344      |
# |    total_timesteps | 178752   |
# | train/             |          |
# |    actor_loss      | -149     |
# |    critic_loss     | 161      |
# |    ent_coef        | 0.308    |
# |    ent_coef_loss   | -7.5     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11109    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.3     |
# |    ep_rew_mean     | 489      |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 517      |
# |    time_elapsed    | 359      |
# |    total_timesteps | 186000   |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 139      |
# |    ent_coef        | 0.296    |
# |    ent_coef_loss   | -8.01    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11562    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.8     |
# |    ep_rew_mean     | 470      |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 517      |
# |    time_elapsed    | 373      |
# |    total_timesteps | 193408   |
# | train/             |          |
# |    actor_loss      | -162     |
# |    critic_loss     | 190      |
# |    ent_coef        | 0.284    |
# |    ent_coef_loss   | -6.77    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 12025    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.7     |
# |    ep_rew_mean     | 506      |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 517      |
# |    time_elapsed    | 387      |
# |    total_timesteps | 200800   |
# | train/             |          |
# |    actor_loss      | -172     |
# |    critic_loss     | 155      |
# |    ent_coef        | 0.272    |
# |    ent_coef_loss   | -7.88    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 12487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.2     |
# |    ep_rew_mean     | 504      |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 517      |
# |    time_elapsed    | 401      |
# |    total_timesteps | 208208   |
# | train/             |          |
# |    actor_loss      | -163     |
# |    critic_loss     | 189      |
# |    ent_coef        | 0.261    |
# |    ent_coef_loss   | -7.72    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 12950    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.7     |
# |    ep_rew_mean     | 516      |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 518      |
# |    time_elapsed    | 416      |
# |    total_timesteps | 215536   |
# | train/             |          |
# |    actor_loss      | -166     |
# |    critic_loss     | 155      |
# |    ent_coef        | 0.25     |
# |    ent_coef_loss   | -8.38    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13408    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.5     |
# |    ep_rew_mean     | 535      |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 517      |
# |    time_elapsed    | 430      |
# |    total_timesteps | 222992   |
# | train/             |          |
# |    actor_loss      | -170     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.24     |
# |    ent_coef_loss   | -7.96    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13874    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.5     |
# |    ep_rew_mean     | 530      |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 517      |
# |    time_elapsed    | 444      |
# |    total_timesteps | 229984   |
# | train/             |          |
# |    actor_loss      | -178     |
# |    critic_loss     | 191      |
# |    ent_coef        | 0.231    |
# |    ent_coef_loss   | -6.92    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14311    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.3     |
# |    ep_rew_mean     | 548      |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 517      |
# |    time_elapsed    | 458      |
# |    total_timesteps | 237216   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 158      |
# |    ent_coef        | 0.222    |
# |    ent_coef_loss   | -6.82    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14763    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.9     |
# |    ep_rew_mean     | 564      |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 518      |
# |    time_elapsed    | 472      |
# |    total_timesteps | 244816   |
# | train/             |          |
# |    actor_loss      | -186     |
# |    critic_loss     | 135      |
# |    ent_coef        | 0.213    |
# |    ent_coef_loss   | -6.94    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15238    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.6     |
# |    ep_rew_mean     | 575      |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 517      |
# |    time_elapsed    | 486      |
# |    total_timesteps | 252112   |
# | train/             |          |
# |    actor_loss      | -177     |
# |    critic_loss     | 132      |
# |    ent_coef        | 0.205    |
# |    ent_coef_loss   | -6.69    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15694    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.7     |
# |    ep_rew_mean     | 580      |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 517      |
# |    time_elapsed    | 501      |
# |    total_timesteps | 259536   |
# | train/             |          |
# |    actor_loss      | -202     |
# |    critic_loss     | 191      |
# |    ent_coef        | 0.197    |
# |    ent_coef_loss   | -6.48    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16158    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.8     |
# |    ep_rew_mean     | 583      |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 517      |
# |    time_elapsed    | 516      |
# |    total_timesteps | 266864   |
# | train/             |          |
# |    actor_loss      | -199     |
# |    critic_loss     | 168      |
# |    ent_coef        | 0.19     |
# |    ent_coef_loss   | -5.95    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16616    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.8     |
# |    ep_rew_mean     | 596      |
# | time/              |          |
# |    episodes        | 3700     |
# |    fps             | 518      |
# |    time_elapsed    | 528      |
# |    total_timesteps | 274016   |
# | train/             |          |
# |    actor_loss      | -208     |
# |    critic_loss     | 131      |
# |    ent_coef        | 0.183    |
# |    ent_coef_loss   | -5.52    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17063    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.1     |
# |    ep_rew_mean     | 601      |
# | time/              |          |
# |    episodes        | 3800     |
# |    fps             | 518      |
# |    time_elapsed    | 542      |
# |    total_timesteps | 281280   |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 130      |
# |    ent_coef        | 0.176    |
# |    ent_coef_loss   | -4.88    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17517    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.5     |
# |    ep_rew_mean     | 614      |
# | time/              |          |
# |    episodes        | 3900     |
# |    fps             | 518      |
# |    time_elapsed    | 557      |
# |    total_timesteps | 288624   |
# | train/             |          |
# |    actor_loss      | -212     |
# |    critic_loss     | 129      |
# |    ent_coef        | 0.17     |
# |    ent_coef_loss   | -5.17    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17976    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.9     |
# |    ep_rew_mean     | 622      |
# | time/              |          |
# |    episodes        | 4000     |
# |    fps             | 518      |
# |    time_elapsed    | 571      |
# |    total_timesteps | 296096   |
# | train/             |          |
# |    actor_loss      | -205     |
# |    critic_loss     | 166      |
# |    ent_coef        | 0.165    |
# |    ent_coef_loss   | -3.6     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18443    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.7     |
# |    ep_rew_mean     | 621      |
# | time/              |          |
# |    episodes        | 4100     |
# |    fps             | 518      |
# |    time_elapsed    | 585      |
# |    total_timesteps | 303296   |
# | train/             |          |
# |    actor_loss      | -232     |
# |    critic_loss     | 140      |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -3.33    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18893    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.8     |
# |    ep_rew_mean     | 625      |
# | time/              |          |
# |    episodes        | 4200     |
# |    fps             | 517      |
# |    time_elapsed    | 601      |
# |    total_timesteps | 311008   |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 171      |
# |    ent_coef        | 0.154    |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19375    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.9     |
# |    ep_rew_mean     | 626      |
# | time/              |          |
# |    episodes        | 4300     |
# |    fps             | 517      |
# |    time_elapsed    | 615      |
# |    total_timesteps | 318384   |
# | train/             |          |
# |    actor_loss      | -225     |
# |    critic_loss     | 159      |
# |    ent_coef        | 0.15     |
# |    ent_coef_loss   | -0.147   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19836    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.8     |
# |    ep_rew_mean     | 634      |
# | time/              |          |
# |    episodes        | 4400     |
# |    fps             | 518      |
# |    time_elapsed    | 628      |
# |    total_timesteps | 325824   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 131      |
# |    ent_coef        | 0.145    |
# |    ent_coef_loss   | -1.36    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20301    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.7     |
# |    ep_rew_mean     | 638      |
# | time/              |          |
# |    episodes        | 4500     |
# |    fps             | 518      |
# |    time_elapsed    | 642      |
# |    total_timesteps | 333296   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 139      |
# |    ent_coef        | 0.141    |
# |    ent_coef_loss   | -2.39    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20768    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.8     |
# |    ep_rew_mean     | 645      |
# | time/              |          |
# |    episodes        | 4600     |
# |    fps             | 519      |
# |    time_elapsed    | 655      |
# |    total_timesteps | 340512   |
# | train/             |          |
# |    actor_loss      | -239     |
# |    critic_loss     | 125      |
# |    ent_coef        | 0.137    |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21219    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.8     |
# |    ep_rew_mean     | 659      |
# | time/              |          |
# |    episodes        | 4700     |
# |    fps             | 520      |
# |    time_elapsed    | 669      |
# |    total_timesteps | 348176   |
# | train/             |          |
# |    actor_loss      | -235     |
# |    critic_loss     | 131      |
# |    ent_coef        | 0.134    |
# |    ent_coef_loss   | -0.999   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21698    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.3     |
# |    ep_rew_mean     | 652      |
# | time/              |          |
# |    episodes        | 4800     |
# |    fps             | 520      |
# |    time_elapsed    | 682      |
# |    total_timesteps | 355648   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 135      |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | 0.726    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22165    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74       |
# |    ep_rew_mean     | 654      |
# | time/              |          |
# |    episodes        | 4900     |
# |    fps             | 521      |
# |    time_elapsed    | 695      |
# |    total_timesteps | 362992   |
# | train/             |          |
# |    actor_loss      | -242     |
# |    critic_loss     | 157      |
# |    ent_coef        | 0.13     |
# |    ent_coef_loss   | -0.61    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22624    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.2     |
# |    ep_rew_mean     | 657      |
# | time/              |          |
# |    episodes        | 5000     |
# |    fps             | 521      |
# |    time_elapsed    | 710      |
# |    total_timesteps | 370608   |
# | train/             |          |
# |    actor_loss      | -242     |
# |    critic_loss     | 137      |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23100    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76       |
# |    ep_rew_mean     | 663      |
# | time/              |          |
# |    episodes        | 5100     |
# |    fps             | 520      |
# |    time_elapsed    | 725      |
# |    total_timesteps | 378000   |
# | train/             |          |
# |    actor_loss      | -233     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -0.182   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23562    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.9     |
# |    ep_rew_mean     | 668      |
# | time/              |          |
# |    episodes        | 5200     |
# |    fps             | 520      |
# |    time_elapsed    | 740      |
# |    total_timesteps | 385456   |
# | train/             |          |
# |    actor_loss      | -240     |
# |    critic_loss     | 144      |
# |    ent_coef        | 0.125    |
# |    ent_coef_loss   | 0.21     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24028    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.1     |
# |    ep_rew_mean     | 670      |
# | time/              |          |
# |    episodes        | 5300     |
# |    fps             | 520      |
# |    time_elapsed    | 755      |
# |    total_timesteps | 392784   |
# | train/             |          |
# |    actor_loss      | -256     |
# |    critic_loss     | 130      |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24486    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.6     |
# |    ep_rew_mean     | 681      |
# | time/              |          |
# |    episodes        | 5400     |
# |    fps             | 520      |
# |    time_elapsed    | 769      |
# |    total_timesteps | 400304   |
# | train/             |          |
# |    actor_loss      | -265     |
# |    critic_loss     | 106      |
# |    ent_coef        | 0.125    |
# |    ent_coef_loss   | 0.773    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24956    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.8     |
# |    ep_rew_mean     | 688      |
# | time/              |          |
# |    episodes        | 5500     |
# |    fps             | 520      |
# |    time_elapsed    | 783      |
# |    total_timesteps | 407856   |
# | train/             |          |
# |    actor_loss      | -254     |
# |    critic_loss     | 91.7     |
# |    ent_coef        | 0.125    |
# |    ent_coef_loss   | 0.601    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.1     |
# |    ep_rew_mean     | 669      |
# | time/              |          |
# |    episodes        | 5600     |
# |    fps             | 520      |
# |    time_elapsed    | 797      |
# |    total_timesteps | 415360   |
# | train/             |          |
# |    actor_loss      | -274     |
# |    critic_loss     | 133      |
# |    ent_coef        | 0.123    |
# |    ent_coef_loss   | 0.206    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25897    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.7     |
# |    ep_rew_mean     | 672      |
# | time/              |          |
# |    episodes        | 5700     |
# |    fps             | 520      |
# |    time_elapsed    | 813      |
# |    total_timesteps | 423312   |
# | train/             |          |
# |    actor_loss      | -278     |
# |    critic_loss     | 113      |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | 0.796    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26394    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.8     |
# |    ep_rew_mean     | 688      |
# | time/              |          |
# |    episodes        | 5800     |
# |    fps             | 520      |
# |    time_elapsed    | 828      |
# |    total_timesteps | 431056   |
# | train/             |          |
# |    actor_loss      | -268     |
# |    critic_loss     | 115      |
# |    ent_coef        | 0.122    |
# |    ent_coef_loss   | 1.16     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26878    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.8     |
# |    ep_rew_mean     | 707      |
# | time/              |          |
# |    episodes        | 5900     |
# |    fps             | 519      |
# |    time_elapsed    | 843      |
# |    total_timesteps | 438720   |
# | train/             |          |
# |    actor_loss      | -259     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.123    |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27357    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.3     |
# |    ep_rew_mean     | 689      |
# | time/              |          |
# |    episodes        | 6000     |
# |    fps             | 519      |
# |    time_elapsed    | 858      |
# |    total_timesteps | 446096   |
# | train/             |          |
# |    actor_loss      | -271     |
# |    critic_loss     | 176      |
# |    ent_coef        | 0.123    |
# |    ent_coef_loss   | -0.344   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27818    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.2     |
# |    ep_rew_mean     | 703      |
# | time/              |          |
# |    episodes        | 6100     |
# |    fps             | 519      |
# |    time_elapsed    | 873      |
# |    total_timesteps | 453584   |
# | train/             |          |
# |    actor_loss      | -270     |
# |    critic_loss     | 94.8     |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -0.418   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28286    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.1     |
# |    ep_rew_mean     | 691      |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 519      |
# |    time_elapsed    | 887      |
# |    total_timesteps | 461152   |
# | train/             |          |
# |    actor_loss      | -253     |
# |    critic_loss     | 124      |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28759    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.4     |
# |    ep_rew_mean     | 702      |
# | time/              |          |
# |    episodes        | 6300     |
# |    fps             | 520      |
# |    time_elapsed    | 901      |
# |    total_timesteps | 468768   |
# | train/             |          |
# |    actor_loss      | -280     |
# |    critic_loss     | 169      |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | 0.321    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 29235    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.1     |
# |    ep_rew_mean     | 718      |
# | time/              |          |
# |    episodes        | 6400     |
# |    fps             | 520      |
# |    time_elapsed    | 915      |
# |    total_timesteps | 476448   |
# | train/             |          |
# |    actor_loss      | -268     |
# |    critic_loss     | 111      |
# |    ent_coef        | 0.128    |
# |    ent_coef_loss   | -0.425   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 29715    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.7     |
# |    ep_rew_mean     | 724      |
# | time/              |          |
# |    episodes        | 6500     |
# |    fps             | 520      |
# |    time_elapsed    | 930      |
# |    total_timesteps | 484032   |
# | train/             |          |
# |    actor_loss      | -276     |
# |    critic_loss     | 111      |
# |    ent_coef        | 0.13     |
# |    ent_coef_loss   | -0.895   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 30189    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.6     |
# |    ep_rew_mean     | 745      |
# | time/              |          |
# |    episodes        | 6600     |
# |    fps             | 520      |
# |    time_elapsed    | 945      |
# |    total_timesteps | 491584   |
# | train/             |          |
# |    actor_loss      | -291     |
# |    critic_loss     | 118      |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | 0.102    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 30661    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.9     |
# |    ep_rew_mean     | 723      |
# | time/              |          |
# |    episodes        | 6700     |
# |    fps             | 519      |
# |    time_elapsed    | 961      |
# |    total_timesteps | 499792   |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 88.4     |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | 0.018    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31174    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.8     |
# |    ep_rew_mean     | 728      |
# | time/              |          |
# |    episodes        | 6800     |
# |    fps             | 519      |
# |    time_elapsed    | 977      |
# |    total_timesteps | 507536   |
# | train/             |          |
# |    actor_loss      | -277     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | 0.623    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31658    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.5     |
# |    ep_rew_mean     | 735      |
# | time/              |          |
# |    episodes        | 6900     |
# |    fps             | 519      |
# |    time_elapsed    | 993      |
# |    total_timesteps | 515584   |
# | train/             |          |
# |    actor_loss      | -285     |
# |    critic_loss     | 108      |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | -0.601   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 32161    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80.1     |
# |    ep_rew_mean     | 740      |
# | time/              |          |
# |    episodes        | 7000     |
# |    fps             | 518      |
# |    time_elapsed    | 1009     |
# |    total_timesteps | 523728   |
# | train/             |          |
# |    actor_loss      | -282     |
# |    critic_loss     | 93.2     |
# |    ent_coef        | 0.127    |
# |    ent_coef_loss   | 0.467    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 32670    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.1     |
# |    ep_rew_mean     | 742      |
# | time/              |          |
# |    episodes        | 7100     |
# |    fps             | 518      |
# |    time_elapsed    | 1025     |
# |    total_timesteps | 531552   |
# | train/             |          |
# |    actor_loss      | -280     |
# |    critic_loss     | 123      |
# |    ent_coef        | 0.128    |
# |    ent_coef_loss   | -0.926   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33159    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.6     |
# |    ep_rew_mean     | 727      |
# | time/              |          |
# |    episodes        | 7200     |
# |    fps             | 518      |
# |    time_elapsed    | 1041     |
# |    total_timesteps | 539680   |
# | train/             |          |
# |    actor_loss      | -268     |
# |    critic_loss     | 122      |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -0.145   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33667    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.6     |
# |    ep_rew_mean     | 720      |
# | time/              |          |
# |    episodes        | 7300     |
# |    fps             | 518      |
# |    time_elapsed    | 1056     |
# |    total_timesteps | 547552   |
# | train/             |          |
# |    actor_loss      | -294     |
# |    critic_loss     | 106      |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | 0.673    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 34159    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.3     |
# |    ep_rew_mean     | 731      |
# | time/              |          |
# |    episodes        | 7400     |
# |    fps             | 518      |
# |    time_elapsed    | 1071     |
# |    total_timesteps | 555488   |
# | train/             |          |
# |    actor_loss      | -273     |
# |    critic_loss     | 182      |
# |    ent_coef        | 0.125    |
# |    ent_coef_loss   | -0.163   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 34655    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.3     |
# |    ep_rew_mean     | 751      |
# | time/              |          |
# |    episodes        | 7500     |
# |    fps             | 518      |
# |    time_elapsed    | 1087     |
# |    total_timesteps | 563424   |
# | train/             |          |
# |    actor_loss      | -283     |
# |    critic_loss     | 118      |
# |    ent_coef        | 0.128    |
# |    ent_coef_loss   | 1.21     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 35151    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77       |
# |    ep_rew_mean     | 749      |
# | time/              |          |
# |    episodes        | 7600     |
# |    fps             | 517      |
# |    time_elapsed    | 1102     |
# |    total_timesteps | 571104   |
# | train/             |          |
# |    actor_loss      | -280     |
# |    critic_loss     | 94.8     |
# |    ent_coef        | 0.128    |
# |    ent_coef_loss   | -0.835   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 35631    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.8     |
# |    ep_rew_mean     | 744      |
# | time/              |          |
# |    episodes        | 7700     |
# |    fps             | 517      |
# |    time_elapsed    | 1118     |
# |    total_timesteps | 578736   |
# | train/             |          |
# |    actor_loss      | -280     |
# |    critic_loss     | 102      |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | -0.39    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36108    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.7     |
# |    ep_rew_mean     | 745      |
# | time/              |          |
# |    episodes        | 7800     |
# |    fps             | 517      |
# |    time_elapsed    | 1132     |
# |    total_timesteps | 586192   |
# | train/             |          |
# |    actor_loss      | -303     |
# |    critic_loss     | 125      |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | -0.391   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36574    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.4     |
# |    ep_rew_mean     | 744      |
# | time/              |          |
# |    episodes        | 7900     |
# |    fps             | 517      |
# |    time_elapsed    | 1148     |
# |    total_timesteps | 593968   |
# | train/             |          |
# |    actor_loss      | -288     |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.131    |
# |    ent_coef_loss   | -0.851   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 37060    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.1     |
# |    ep_rew_mean     | 759      |
# | time/              |          |
# |    episodes        | 8000     |
# |    fps             | 516      |
# |    time_elapsed    | 1164     |
# |    total_timesteps | 601840   |
# | train/             |          |
# |    actor_loss      | -290     |
# |    critic_loss     | 139      |
# |    ent_coef        | 0.131    |
# |    ent_coef_loss   | -0.0193  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 37552    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.5     |
# |    ep_rew_mean     | 774      |
# | time/              |          |
# |    episodes        | 8100     |
# |    fps             | 517      |
# |    time_elapsed    | 1179     |
# |    total_timesteps | 609792   |
# | train/             |          |
# |    actor_loss      | -293     |
# |    critic_loss     | 118      |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | 0.437    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38049    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79       |
# |    ep_rew_mean     | 781      |
# | time/              |          |
# |    episodes        | 8200     |
# |    fps             | 517      |
# |    time_elapsed    | 1194     |
# |    total_timesteps | 617664   |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 104      |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | 0.0849   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38541    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81       |
# |    ep_rew_mean     | 775      |
# | time/              |          |
# |    episodes        | 8300     |
# |    fps             | 516      |
# |    time_elapsed    | 1210     |
# |    total_timesteps | 625632   |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 132      |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | -0.945   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 39039    |
# ...
# |    ep_len_mean     | 2.09e+03  |
# |    ep_rew_mean     | 9.84e+04  |
# | time/              |           |
# |    episodes        | 19200     |
# |    fps             | 515       |
# |    time_elapsed    | 15231     |
# |    total_timesteps | 7854864   |
# | train/             |           |
# |    actor_loss      | -3.76e+03 |
# |    critic_loss     | 1.04e+04  |
# |    ent_coef        | 0.685     |
# |    ent_coef_loss   | -0.0866   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 490866    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.71e+03  |
# |    ep_rew_mean     | 3.31e+05  |
# | time/              |           |
# |    episodes        | 19300     |
# |    fps             | 516       |
# |    time_elapsed    | 16549     |
# |    total_timesteps | 8541472   |
# | train/             |           |
# |    actor_loss      | -3.69e+03 |
# |    critic_loss     | 1.74e+03  |
# |    ent_coef        | 0.8       |
# |    ent_coef_loss   | 0.00464   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 533779    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.03e+03  |
# |    ep_rew_mean     | 2e+05     |
# | time/              |           |
# |    episodes        | 19400     |
# |    fps             | 516       |
# |    time_elapsed    | 17238     |
# |    total_timesteps | 8898336   |
# | train/             |           |
# |    actor_loss      | -3.75e+03 |
# |    critic_loss     | 1.89e+04  |
# |    ent_coef        | 0.757     |
# |    ent_coef_loss   | 0.208     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 556083    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.7e+03   |
# |    ep_rew_mean     | 2.33e+05  |
# | time/              |           |
# |    episodes        | 19500     |
# |    fps             | 515       |
# |    time_elapsed    | 18164     |
# |    total_timesteps | 9372720   |
# | train/             |           |
# |    actor_loss      | -3.79e+03 |
# |    critic_loss     | 3.67e+03  |
# |    ent_coef        | 0.762     |
# |    ent_coef_loss   | 0.151     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 585732    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.69e+03  |
# |    ep_rew_mean     | 2.36e+05  |
# | time/              |           |
# |    episodes        | 19600     |
# |    fps             | 515       |
# |    time_elapsed    | 19075     |
# |    total_timesteps | 9841408   |
# | train/             |           |
# |    actor_loss      | -3.83e+03 |
# |    critic_loss     | 3.06e+03  |
# |    ent_coef        | 0.734     |
# |    ent_coef_loss   | 0.00815   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 615025    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.69e+03  |
# |    ep_rew_mean     | 2.33e+05  |
# | time/              |           |
# |    episodes        | 19700     |
# |    fps             | 515       |
# |    time_elapsed    | 20031     |
# |    total_timesteps | 10332000  |
# | train/             |           |
# |    actor_loss      | -3.93e+03 |
# |    critic_loss     | 5.47e+03  |
# |    ent_coef        | 0.655     |
# |    ent_coef_loss   | 0.00803   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 645687    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.89e+03  |
# |    ep_rew_mean     | 2.45e+05  |
# | time/              |           |
# |    episodes        | 19800     |
# |    fps             | 516       |
# |    time_elapsed    | 20976     |
# |    total_timesteps | 10825376  |
# | train/             |           |
# |    actor_loss      | -3.89e+03 |
# |    critic_loss     | 1.64e+03  |
# |    ent_coef        | 0.668     |
# |    ent_coef_loss   | -0.126    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 676523    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.33e+03  |
# |    ep_rew_mean     | 2.15e+05  |
# | time/              |           |
# |    episodes        | 19900     |
# |    fps             | 516       |
# |    time_elapsed    | 21774     |
# |    total_timesteps | 11236400  |
# | train/             |           |
# |    actor_loss      | -3.97e+03 |
# |    critic_loss     | 2.86e+03  |
# |    ent_coef        | 0.523     |
# |    ent_coef_loss   | -0.175    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 702212    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.33e+03  |
# |    ep_rew_mean     | 2.72e+05  |
# | time/              |           |
# |    episodes        | 20000     |
# |    fps             | 515       |
# |    time_elapsed    | 22848     |
# |    total_timesteps | 11786240  |
# | train/             |           |
# |    actor_loss      | -4.15e+03 |
# |    critic_loss     | 1.87e+03  |
# |    ent_coef        | 0.524     |
# |    ent_coef_loss   | 0.234     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 736577    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.6e+03   |
# |    ep_rew_mean     | 2.37e+05  |
# | time/              |           |
# |    episodes        | 20100     |
# |    fps             | 515       |
# |    time_elapsed    | 23729     |
# |    total_timesteps | 12233248  |
# | train/             |           |
# |    actor_loss      | -4.11e+03 |
# |    critic_loss     | 6.15e+03  |
# |    ent_coef        | 0.486     |
# |    ent_coef_loss   | 0.309     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 764515    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.58e+03  |
# |    ep_rew_mean     | 2.91e+05  |
# | time/              |           |
# |    episodes        | 20200     |
# |    fps             | 515       |
# |    time_elapsed    | 24847     |
# |    total_timesteps | 12809504  |
# | train/             |           |
# |    actor_loss      | -4.22e+03 |
# |    critic_loss     | 1.36e+04  |
# |    ent_coef        | 0.584     |
# |    ent_coef_loss   | 0.307     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 800531    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.65e+03  |
# |    ep_rew_mean     | 2.49e+05  |
# | time/              |           |
# |    episodes        | 20300     |
# |    fps             | 515       |
# |    time_elapsed    | 25725     |
# |    total_timesteps | 13264448  |
# | train/             |           |
# |    actor_loss      | -4.25e+03 |
# |    critic_loss     | 2.05e+04  |
# |    ent_coef        | 0.649     |
# |    ent_coef_loss   | 0.207     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 828965    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.26e+03  |
# |    ep_rew_mean     | 3.38e+05  |
# | time/              |           |
# |    episodes        | 20400     |
# |    fps             | 515       |
# |    time_elapsed    | 26963     |
# |    total_timesteps | 13901808  |
# | train/             |           |
# |    actor_loss      | -4.42e+03 |
# |    critic_loss     | 2.93e+03  |
# |    ent_coef        | 0.556     |
# |    ent_coef_loss   | 0.017     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 868800    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.51e+03  |
# |    ep_rew_mean     | 1.9e+05   |
# | time/              |           |
# |    episodes        | 20500     |
# |    fps             | 515       |
# |    time_elapsed    | 27693     |
# |    total_timesteps | 14281968  |
# | train/             |           |
# |    actor_loss      | -4.41e+03 |
# |    critic_loss     | 4.8e+03   |
# |    ent_coef        | 0.573     |
# |    ent_coef_loss   | 0.0168    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 892560    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.91e+03  |
# |    ep_rew_mean     | 3.25e+05  |
# | time/              |           |
# |    episodes        | 20600     |
# |    fps             | 515       |
# |    time_elapsed    | 28789     |
# |    total_timesteps | 14853920  |
# | train/             |           |
# |    actor_loss      | -4.28e+03 |
# |    critic_loss     | 1.9e+04   |
# |    ent_coef        | 0.717     |
# |    ent_coef_loss   | -0.00116  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 928307    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.06e+03  |
# |    ep_rew_mean     | 2.81e+05  |
# | time/              |           |
# |    episodes        | 20700     |
# |    fps             | 516       |
# |    time_elapsed    | 29754     |
# |    total_timesteps | 15357120  |
# | train/             |           |
# |    actor_loss      | -4.31e+03 |
# |    critic_loss     | 2.82e+04  |
# |    ent_coef        | 0.683     |
# |    ent_coef_loss   | -0.182    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 959757    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.76e+03  |
# |    ep_rew_mean     | 3.78e+05  |
# | time/              |           |
# |    episodes        | 20800     |
# |    fps             | 516       |
# |    time_elapsed    | 31065     |
# |    total_timesteps | 16037504  |
# | train/             |           |
# |    actor_loss      | -4.51e+03 |
# |    critic_loss     | 4.67e+03  |
# |    ent_coef        | 0.59      |
# |    ent_coef_loss   | -0.00704  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1002281   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.71e+03  |
# |    ep_rew_mean     | 2.64e+05  |
# | time/              |           |
# |    episodes        | 20900     |
# |    fps             | 516       |
# |    time_elapsed    | 31869     |
# |    total_timesteps | 16454848  |
# | train/             |           |
# |    actor_loss      | -4.63e+03 |
# |    critic_loss     | 3.72e+03  |
# |    ent_coef        | 0.48      |
# |    ent_coef_loss   | -0.0792   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1028365   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.03e+03  |
# |    ep_rew_mean     | 2.27e+05  |
# | time/              |           |
# |    episodes        | 21000     |
# |    fps             | 516       |
# |    time_elapsed    | 32693     |
# |    total_timesteps | 16889424  |
# | train/             |           |
# |    actor_loss      | -4.58e+03 |
# |    critic_loss     | 5.28e+03  |
# |    ent_coef        | 0.55      |
# |    ent_coef_loss   | 0.106     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1055526   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.1e+03   |
# |    ep_rew_mean     | 2.88e+05  |
# | time/              |           |
# |    episodes        | 21100     |
# |    fps             | 516       |
# |    time_elapsed    | 33619     |
# |    total_timesteps | 17376192  |
# | train/             |           |
# |    actor_loss      | -4.62e+03 |
# |    critic_loss     | 5.99e+03  |
# |    ent_coef        | 0.625     |
# |    ent_coef_loss   | -0.0207   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1085949   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.05e+03  |
# |    ep_rew_mean     | 3.43e+05  |
# | time/              |           |
# |    episodes        | 21200     |
# |    fps             | 516       |
# |    time_elapsed    | 34851     |
# |    total_timesteps | 18015792  |
# | train/             |           |
# |    actor_loss      | -4.53e+03 |
# |    critic_loss     | 2.93e+03  |
# |    ent_coef        | 0.663     |
# |    ent_coef_loss   | -0.0848   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1125924   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.03e+03  |
# |    ep_rew_mean     | 3.45e+05  |
# | time/              |           |
# |    episodes        | 21300     |
# |    fps             | 516       |
# |    time_elapsed    | 36012     |
# |    total_timesteps | 18614016  |
# | train/             |           |
# |    actor_loss      | -4.76e+03 |
# |    critic_loss     | 2.49e+03  |
# |    ent_coef        | 0.497     |
# |    ent_coef_loss   | -0.559    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1163313   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.68e+03  |
# |    ep_rew_mean     | 3.28e+05  |
# | time/              |           |
# |    episodes        | 21400     |
# |    fps             | 516       |
# |    time_elapsed    | 37113     |
# |    total_timesteps | 19181424  |
# | train/             |           |
# |    actor_loss      | -4.89e+03 |
# |    critic_loss     | 2.64e+03  |
# |    ent_coef        | 0.494     |
# |    ent_coef_loss   | 0.28      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1198776   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.5e+03   |
# |    ep_rew_mean     | 3.83e+05  |
# | time/              |           |
# |    episodes        | 21500     |
# |    fps             | 516       |
# |    time_elapsed    | 38431     |
# |    total_timesteps | 19863344  |
# | train/             |           |
# |    actor_loss      | -4.96e+03 |
# |    critic_loss     | 4.05e+03  |
# |    ent_coef        | 0.445     |
# |    ent_coef_loss   | -0.206    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1241396   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.5e+03   |
# |    ep_rew_mean     | 3.25e+05  |
# | time/              |           |
# |    episodes        | 21600     |
# |    fps             | 516       |
# |    time_elapsed    | 39407     |
# |    total_timesteps | 20370400  |
# | train/             |           |
# |    actor_loss      | -4.95e+03 |
# |    critic_loss     | 1.08e+03  |
# |    ent_coef        | 0.512     |
# |    ent_coef_loss   | 0.189     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1273087   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.75e+03  |
# |    ep_rew_mean     | 3.43e+05  |
# | time/              |           |
# |    episodes        | 21700     |
# |    fps             | 517       |
# |    time_elapsed    | 40588     |
# |    total_timesteps | 20991200  |
# | train/             |           |
# |    actor_loss      | -4.87e+03 |
# |    critic_loss     | 5.06e+03  |
# |    ent_coef        | 0.617     |
# |    ent_coef_loss   | -0.272    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1311887   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.22e+03  |
# |    ep_rew_mean     | 3.73e+05  |
# | time/              |           |
# |    episodes        | 21800     |
# |    fps             | 517       |
# |    time_elapsed    | 41675     |
# |    total_timesteps | 21563456  |
# | train/             |           |
# |    actor_loss      | -4.61e+03 |
# |    critic_loss     | 2.3e+03   |
# |    ent_coef        | 0.726     |
# |    ent_coef_loss   | 0.0609    |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1347653   |
# ----------------------------------

# %%
model.save("trained_models/g1-forward/sac")
