# %%
import gym
import numpy as np
import torch

from environments import *

from stable_baselines3 import SAC, HerReplayBuffer
from stable_baselines3.common.cmd_util import make_vec_env
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /home/user/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/cmd_util.py:5: FutureWarning: Module ``common.cmd_util`` has been renamed to ``common.env_util`` and will be removed in the future.
#   warnings.warn(

# %%
env = make_vec_env("G1GoalDist-v1", 32, env_kwargs=dict(
    mode='direction',
))
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/gym/core.py:329: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/user/anaconda3/lib/python3.9/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
model = SAC(
    "MlpPolicy", 
    env, 
    verbose=1,
    batch_size=4096,
    buffer_size=1000000,
    policy_kwargs=dict(        
        net_arch=[512, 512, 512, 512], 
        activation_fn=torch.nn.ELU,
        n_critics=5,
    ),
    tensorboard_log="./logs/sac/"
)
# Out:
# Using cuda device

# %%
model.set_parameters("trained_models/direction")

# %%
model.learn(
    total_timesteps=int(5e7), 
    log_interval=100,
    tb_log_name='direction',
    reset_num_timesteps=False,
)
# Out:
# Logging to ./logs/sac/direction_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41       |
# |    ep_rew_mean     | -149     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 328      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4832     |
# | train/             |          |
# |    actor_loss      | 31.3     |
# |    critic_loss     | 36.6     |
# |    ent_coef        | 0.837    |
# |    ent_coef_loss   | -2.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 147      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.9     |
# |    ep_rew_mean     | -84.7    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 323      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 8608     |
# | train/             |          |
# |    actor_loss      | 29.1     |
# |    critic_loss     | 26.2     |
# |    ent_coef        | 0.772    |
# |    ent_coef_loss   | -3.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.7     |
# |    ep_rew_mean     | -54.1    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 319      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 12096    |
# | train/             |          |
# |    actor_loss      | 28.7     |
# |    critic_loss     | 21.5     |
# |    ent_coef        | 0.727    |
# |    ent_coef_loss   | -4.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 374      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.2     |
# |    ep_rew_mean     | -52.1    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 316      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 15584    |
# | train/             |          |
# |    actor_loss      | 28.4     |
# |    critic_loss     | 20.9     |
# |    ent_coef        | 0.689    |
# |    ent_coef_loss   | -5.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.1     |
# |    ep_rew_mean     | -49.9    |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 314      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 18848    |
# | train/             |          |
# |    actor_loss      | 28.3     |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.659    |
# |    ent_coef_loss   | -5.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 585      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.7     |
# |    ep_rew_mean     | -33.4    |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 313      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 22144    |
# | train/             |          |
# |    actor_loss      | 28.7     |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.631    |
# |    ent_coef_loss   | -6.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 688      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.4     |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 313      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 25440    |
# | train/             |          |
# |    actor_loss      | 28.5     |
# |    critic_loss     | 25.6     |
# |    ent_coef        | 0.607    |
# |    ent_coef_loss   | -6.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 791      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.1     |
# |    ep_rew_mean     | -23.2    |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 312      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 28640    |
# | train/             |          |
# |    actor_loss      | 28.2     |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.585    |
# |    ent_coef_loss   | -6.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 891      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.5     |
# |    ep_rew_mean     | -17.2    |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 312      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 31648    |
# | train/             |          |
# |    actor_loss      | 27.8     |
# |    critic_loss     | 18.2     |
# |    ent_coef        | 0.565    |
# |    ent_coef_loss   | -7.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 985      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.1     |
# |    ep_rew_mean     | -21.6    |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 311      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 34848    |
# | train/             |          |
# |    actor_loss      | 27.9     |
# |    critic_loss     | 18.2     |
# |    ent_coef        | 0.546    |
# |    ent_coef_loss   | -7.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1085     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.1     |
# |    ep_rew_mean     | -13      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 311      |
# |    time_elapsed    | 121      |
# |    total_timesteps | 37824    |
# | train/             |          |
# |    actor_loss      | 27.8     |
# |    critic_loss     | 19.5     |
# |    ent_coef        | 0.53     |
# |    ent_coef_loss   | -7.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1178     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.2     |
# |    ep_rew_mean     | -8.42    |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 311      |
# |    time_elapsed    | 131      |
# |    total_timesteps | 40800    |
# | train/             |          |
# |    actor_loss      | 28.5     |
# |    critic_loss     | 33.2     |
# |    ent_coef        | 0.514    |
# |    ent_coef_loss   | -7.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1271     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.2     |
# |    ep_rew_mean     | -4.06    |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 310      |
# |    time_elapsed    | 141      |
# |    total_timesteps | 43872    |
# | train/             |          |
# |    actor_loss      | 28.5     |
# |    critic_loss     | 24.1     |
# |    ent_coef        | 0.499    |
# |    ent_coef_loss   | -7.99    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1367     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.4     |
# |    ep_rew_mean     | 0.181    |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 310      |
# |    time_elapsed    | 150      |
# |    total_timesteps | 46816    |
# | train/             |          |
# |    actor_loss      | 27.5     |
# |    critic_loss     | 21.2     |
# |    ent_coef        | 0.484    |
# |    ent_coef_loss   | -8.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1459     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.1     |
# |    ep_rew_mean     | 3.83     |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 310      |
# |    time_elapsed    | 160      |
# |    total_timesteps | 49856    |
# | train/             |          |
# |    actor_loss      | 27.7     |
# |    critic_loss     | 20.1     |
# |    ent_coef        | 0.471    |
# |    ent_coef_loss   | -8.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1554     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.1     |
# |    ep_rew_mean     | -1.04    |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 310      |
# |    time_elapsed    | 170      |
# |    total_timesteps | 52768    |
# | train/             |          |
# |    actor_loss      | 27.3     |
# |    critic_loss     | 19.8     |
# |    ent_coef        | 0.458    |
# |    ent_coef_loss   | -8.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1645     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.8     |
# |    ep_rew_mean     | 6.9      |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 310      |
# |    time_elapsed    | 179      |
# |    total_timesteps | 55744    |
# | train/             |          |
# |    actor_loss      | 26.7     |
# |    critic_loss     | 19       |
# |    ent_coef        | 0.446    |
# |    ent_coef_loss   | -8.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1738     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29       |
# |    ep_rew_mean     | 3.68     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 309      |
# |    time_elapsed    | 189      |
# |    total_timesteps | 58656    |
# | train/             |          |
# |    actor_loss      | 27       |
# |    critic_loss     | 19.6     |
# |    ent_coef        | 0.434    |
# |    ent_coef_loss   | -8.77    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1829     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.8     |
# |    ep_rew_mean     | 9.72     |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 309      |
# |    time_elapsed    | 198      |
# |    total_timesteps | 61536    |
# | train/             |          |
# |    actor_loss      | 26.4     |
# |    critic_loss     | 17.3     |
# |    ent_coef        | 0.423    |
# |    ent_coef_loss   | -8.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1919     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.6     |
# |    ep_rew_mean     | 13.9     |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 309      |
# |    time_elapsed    | 207      |
# |    total_timesteps | 64320    |
# | train/             |          |
# |    actor_loss      | 26.2     |
# |    critic_loss     | 17.5     |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | -9.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2006     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.3     |
# |    ep_rew_mean     | 15.2     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 309      |
# |    time_elapsed    | 217      |
# |    total_timesteps | 67264    |
# | train/             |          |
# |    actor_loss      | 26.5     |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.402    |
# |    ent_coef_loss   | -9.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2098     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.1     |
# |    ep_rew_mean     | 16.9     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 309      |
# |    time_elapsed    | 226      |
# |    total_timesteps | 70176    |
# | train/             |          |
# |    actor_loss      | 25.9     |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.392    |
# |    ent_coef_loss   | -9.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2189     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.7     |
# |    ep_rew_mean     | 17.1     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 309      |
# |    time_elapsed    | 236      |
# |    total_timesteps | 73056    |
# | train/             |          |
# |    actor_loss      | 25.8     |
# |    critic_loss     | 16.7     |
# |    ent_coef        | 0.383    |
# |    ent_coef_loss   | -9.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2279     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.4     |
# |    ep_rew_mean     | 17.3     |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 309      |
# |    time_elapsed    | 245      |
# |    total_timesteps | 75968    |
# | train/             |          |
# |    actor_loss      | 24.7     |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.373    |
# |    ent_coef_loss   | -9.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2370     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 309      |
# |    time_elapsed    | 254      |
# |    total_timesteps | 78784    |
# | train/             |          |
# |    actor_loss      | 24.7     |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.365    |
# |    ent_coef_loss   | -9.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2458     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.8     |
# |    ep_rew_mean     | 22.1     |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 309      |
# |    time_elapsed    | 264      |
# |    total_timesteps | 81760    |
# | train/             |          |
# |    actor_loss      | 23.9     |
# |    critic_loss     | 15.3     |
# |    ent_coef        | 0.356    |
# |    ent_coef_loss   | -9.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2551     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.4     |
# |    ep_rew_mean     | 23.1     |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 309      |
# |    time_elapsed    | 273      |
# |    total_timesteps | 84608    |
# | train/             |          |
# |    actor_loss      | 23.3     |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.347    |
# |    ent_coef_loss   | -9.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2640     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.3     |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 309      |
# |    time_elapsed    | 282      |
# |    total_timesteps | 87456    |
# | train/             |          |
# |    actor_loss      | 23.3     |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.339    |
# |    ent_coef_loss   | -9.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2729     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29       |
# |    ep_rew_mean     | 25.5     |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 309      |
# |    time_elapsed    | 292      |
# |    total_timesteps | 90432    |
# | train/             |          |
# |    actor_loss      | 22.5     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.331    |
# |    ent_coef_loss   | -9.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2822     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29       |
# |    ep_rew_mean     | 25.1     |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 308      |
# |    time_elapsed    | 301      |
# |    total_timesteps | 93312    |
# | train/             |          |
# |    actor_loss      | 21.3     |
# |    critic_loss     | 12.7     |
# |    ent_coef        | 0.323    |
# |    ent_coef_loss   | -9.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2912     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.3     |
# |    ep_rew_mean     | 29.1     |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 308      |
# |    time_elapsed    | 311      |
# |    total_timesteps | 96160    |
# | train/             |          |
# |    actor_loss      | 21.8     |
# |    critic_loss     | 12.7     |
# |    ent_coef        | 0.316    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3001     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.8     |
# |    ep_rew_mean     | 26.8     |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 308      |
# |    time_elapsed    | 320      |
# |    total_timesteps | 99040    |
# | train/             |          |
# |    actor_loss      | 20.8     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.308    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3091     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.4     |
# |    ep_rew_mean     | 31.9     |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 308      |
# |    time_elapsed    | 330      |
# |    total_timesteps | 102016   |
# | train/             |          |
# |    actor_loss      | 20.4     |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.301    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3184     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 31.6     |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 308      |
# |    time_elapsed    | 339      |
# |    total_timesteps | 104992   |
# | train/             |          |
# |    actor_loss      | 19.4     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.294    |
# |    ent_coef_loss   | -9.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3277     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.7     |
# |    ep_rew_mean     | 36.8     |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 308      |
# |    time_elapsed    | 349      |
# |    total_timesteps | 107840   |
# | train/             |          |
# |    actor_loss      | 19.2     |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.287    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3366     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29       |
# |    ep_rew_mean     | 33.1     |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 308      |
# |    time_elapsed    | 358      |
# |    total_timesteps | 110816   |
# | train/             |          |
# |    actor_loss      | 18.9     |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.28     |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3459     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.1     |
# |    ep_rew_mean     | 35.6     |
# | time/              |          |
# |    episodes        | 3700     |
# |    fps             | 308      |
# |    time_elapsed    | 368      |
# |    total_timesteps | 113760   |
# | train/             |          |
# |    actor_loss      | 17.6     |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.273    |
# |    ent_coef_loss   | -10.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3551     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.9     |
# |    ep_rew_mean     | 37.6     |
# | time/              |          |
# |    episodes        | 3800     |
# |    fps             | 308      |
# |    time_elapsed    | 378      |
# |    total_timesteps | 116672   |
# | train/             |          |
# |    actor_loss      | 16.7     |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.267    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3642     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | 39.1     |
# | time/              |          |
# |    episodes        | 3900     |
# |    fps             | 308      |
# |    time_elapsed    | 387      |
# |    total_timesteps | 119616   |
# | train/             |          |
# |    actor_loss      | 16.6     |
# |    critic_loss     | 9.58     |
# |    ent_coef        | 0.261    |
# |    ent_coef_loss   | -10.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3734     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 38.4     |
# | time/              |          |
# |    episodes        | 4000     |
# |    fps             | 308      |
# |    time_elapsed    | 396      |
# |    total_timesteps | 122496   |
# | train/             |          |
# |    actor_loss      | 15.8     |
# |    critic_loss     | 9.24     |
# |    ent_coef        | 0.255    |
# |    ent_coef_loss   | -10.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3824     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | 40.5     |
# | time/              |          |
# |    episodes        | 4100     |
# |    fps             | 308      |
# |    time_elapsed    | 406      |
# |    total_timesteps | 125408   |
# | train/             |          |
# |    actor_loss      | 15.9     |
# |    critic_loss     | 9.37     |
# |    ent_coef        | 0.249    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3915     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.1     |
# |    ep_rew_mean     | 39       |
# | time/              |          |
# |    episodes        | 4200     |
# |    fps             | 308      |
# |    time_elapsed    | 416      |
# |    total_timesteps | 128384   |
# | train/             |          |
# |    actor_loss      | 15.2     |
# |    critic_loss     | 9.06     |
# |    ent_coef        | 0.243    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4008     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.5     |
# |    ep_rew_mean     | 43.3     |
# | time/              |          |
# |    episodes        | 4300     |
# |    fps             | 308      |
# |    time_elapsed    | 425      |
# |    total_timesteps | 131264   |
# | train/             |          |
# |    actor_loss      | 14.9     |
# |    critic_loss     | 8.89     |
# |    ent_coef        | 0.238    |
# |    ent_coef_loss   | -10.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4098     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.3     |
# |    ep_rew_mean     | 38.5     |
# | time/              |          |
# |    episodes        | 4400     |
# |    fps             | 308      |
# |    time_elapsed    | 435      |
# |    total_timesteps | 134304   |
# | train/             |          |
# |    actor_loss      | 14.5     |
# |    critic_loss     | 8.61     |
# |    ent_coef        | 0.232    |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4193     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 42.1     |
# | time/              |          |
# |    episodes        | 4500     |
# |    fps             | 308      |
# |    time_elapsed    | 445      |
# |    total_timesteps | 137344   |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 8.5      |
# |    ent_coef        | 0.227    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.7     |
# |    ep_rew_mean     | 43       |
# | time/              |          |
# |    episodes        | 4600     |
# |    fps             | 308      |
# |    time_elapsed    | 454      |
# |    total_timesteps | 140256   |
# | train/             |          |
# |    actor_loss      | 12.5     |
# |    critic_loss     | 7.73     |
# |    ent_coef        | 0.221    |
# |    ent_coef_loss   | -10.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4379     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.5     |
# |    ep_rew_mean     | 45.8     |
# | time/              |          |
# |    episodes        | 4700     |
# |    fps             | 308      |
# |    time_elapsed    | 464      |
# |    total_timesteps | 143136   |
# | train/             |          |
# |    actor_loss      | 12.4     |
# |    critic_loss     | 7.68     |
# |    ent_coef        | 0.216    |
# |    ent_coef_loss   | -10      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4469     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | 48.3     |
# | time/              |          |
# |    episodes        | 4800     |
# |    fps             | 308      |
# |    time_elapsed    | 473      |
# |    total_timesteps | 146080   |
# | train/             |          |
# |    actor_loss      | 11.7     |
# |    critic_loss     | 7.97     |
# |    ent_coef        | 0.212    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4561     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.9     |
# |    ep_rew_mean     | 48.7     |
# | time/              |          |
# |    episodes        | 4900     |
# |    fps             | 308      |
# |    time_elapsed    | 483      |
# |    total_timesteps | 149120   |
# | train/             |          |
# |    actor_loss      | 10.6     |
# |    critic_loss     | 7.35     |
# |    ent_coef        | 0.207    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4656     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.2     |
# |    ep_rew_mean     | 52.7     |
# | time/              |          |
# |    episodes        | 5000     |
# |    fps             | 308      |
# |    time_elapsed    | 493      |
# |    total_timesteps | 152128   |
# | train/             |          |
# |    actor_loss      | 9.74     |
# |    critic_loss     | 7        |
# |    ent_coef        | 0.202    |
# |    ent_coef_loss   | -10.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4750     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 48.5     |
# | time/              |          |
# |    episodes        | 5100     |
# |    fps             | 308      |
# |    time_elapsed    | 503      |
# |    total_timesteps | 155232   |
# | train/             |          |
# |    actor_loss      | 10.1     |
# |    critic_loss     | 6.91     |
# |    ent_coef        | 0.197    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4847     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 48.1     |
# | time/              |          |
# |    episodes        | 5200     |
# |    fps             | 308      |
# |    time_elapsed    | 513      |
# |    total_timesteps | 158144   |
# | train/             |          |
# |    actor_loss      | 8.61     |
# |    critic_loss     | 6.61     |
# |    ent_coef        | 0.193    |
# |    ent_coef_loss   | -10.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4938     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | 47.4     |
# | time/              |          |
# |    episodes        | 5300     |
# |    fps             | 308      |
# |    time_elapsed    | 522      |
# |    total_timesteps | 161056   |
# | train/             |          |
# |    actor_loss      | 8.5      |
# |    critic_loss     | 6.51     |
# |    ent_coef        | 0.189    |
# |    ent_coef_loss   | -10      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5029     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.3     |
# |    ep_rew_mean     | 53.2     |
# | time/              |          |
# |    episodes        | 5400     |
# |    fps             | 308      |
# |    time_elapsed    | 532      |
# |    total_timesteps | 164128   |
# | train/             |          |
# |    actor_loss      | 7.78     |
# |    critic_loss     | 6.21     |
# |    ent_coef        | 0.184    |
# |    ent_coef_loss   | -9.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5125     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.9     |
# |    ep_rew_mean     | 56.6     |
# | time/              |          |
# |    episodes        | 5500     |
# |    fps             | 308      |
# |    time_elapsed    | 542      |
# |    total_timesteps | 167168   |
# | train/             |          |
# |    actor_loss      | 7.67     |
# |    critic_loss     | 6.72     |
# |    ent_coef        | 0.18     |
# |    ent_coef_loss   | -9.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5220     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.7     |
# |    ep_rew_mean     | 57       |
# | time/              |          |
# |    episodes        | 5600     |
# |    fps             | 308      |
# |    time_elapsed    | 552      |
# |    total_timesteps | 170304   |
# | train/             |          |
# |    actor_loss      | 7.04     |
# |    critic_loss     | 5.97     |
# |    ent_coef        | 0.176    |
# |    ent_coef_loss   | -9.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5318     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.9     |
# |    ep_rew_mean     | 59.2     |
# | time/              |          |
# |    episodes        | 5700     |
# |    fps             | 308      |
# |    time_elapsed    | 563      |
# |    total_timesteps | 173568   |
# | train/             |          |
# |    actor_loss      | 6.28     |
# |    critic_loss     | 6.01     |
# |    ent_coef        | 0.172    |
# |    ent_coef_loss   | -9.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5420     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.8     |
# |    ep_rew_mean     | 59.9     |
# | time/              |          |
# |    episodes        | 5800     |
# |    fps             | 308      |
# |    time_elapsed    | 573      |
# |    total_timesteps | 176512   |
# | train/             |          |
# |    actor_loss      | 5.88     |
# |    critic_loss     | 5.55     |
# |    ent_coef        | 0.168    |
# |    ent_coef_loss   | -9.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5512     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.2     |
# |    ep_rew_mean     | 56.5     |
# | time/              |          |
# |    episodes        | 5900     |
# |    fps             | 307      |
# |    time_elapsed    | 583      |
# |    total_timesteps | 179552   |
# | train/             |          |
# |    actor_loss      | 5.75     |
# |    critic_loss     | 8.61     |
# |    ent_coef        | 0.165    |
# |    ent_coef_loss   | -9.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5607     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.9     |
# |    ep_rew_mean     | 60       |
# | time/              |          |
# |    episodes        | 6000     |
# |    fps             | 307      |
# |    time_elapsed    | 593      |
# |    total_timesteps | 182624   |
# | train/             |          |
# |    actor_loss      | 4.18     |
# |    critic_loss     | 6.35     |
# |    ent_coef        | 0.161    |
# |    ent_coef_loss   | -9.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5703     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.1     |
# |    ep_rew_mean     | 59.8     |
# | time/              |          |
# |    episodes        | 6100     |
# |    fps             | 307      |
# |    time_elapsed    | 602      |
# |    total_timesteps | 185632   |
# | train/             |          |
# |    actor_loss      | 3.66     |
# |    critic_loss     | 5.88     |
# |    ent_coef        | 0.157    |
# |    ent_coef_loss   | -8.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5797     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.7     |
# |    ep_rew_mean     | 60.5     |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 307      |
# |    time_elapsed    | 612      |
# |    total_timesteps | 188736   |
# | train/             |          |
# |    actor_loss      | 3.82     |
# |    critic_loss     | 5.56     |
# |    ent_coef        | 0.154    |
# |    ent_coef_loss   | -9.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5894     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.4     |
# |    ep_rew_mean     | 63.7     |
# | time/              |          |
# |    episodes        | 6300     |
# |    fps             | 307      |
# |    time_elapsed    | 623      |
# |    total_timesteps | 191904   |
# | train/             |          |
# |    actor_loss      | 2.8      |
# |    critic_loss     | 5.39     |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -8.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5993     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.5     |
# |    ep_rew_mean     | 64.4     |
# | time/              |          |
# |    episodes        | 6400     |
# |    fps             | 307      |
# |    time_elapsed    | 633      |
# |    total_timesteps | 195136   |
# | train/             |          |
# |    actor_loss      | 2.75     |
# |    critic_loss     | 5.27     |
# |    ent_coef        | 0.147    |
# |    ent_coef_loss   | -8.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6094     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.4     |
# |    ep_rew_mean     | 62       |
# | time/              |          |
# |    episodes        | 6500     |
# |    fps             | 307      |
# |    time_elapsed    | 643      |
# |    total_timesteps | 198144   |
# | train/             |          |
# |    actor_loss      | 2.21     |
# |    critic_loss     | 5.56     |
# |    ent_coef        | 0.144    |
# |    ent_coef_loss   | -8.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6188     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.6     |
# |    ep_rew_mean     | 62.5     |
# | time/              |          |
# |    episodes        | 6600     |
# |    fps             | 307      |
# |    time_elapsed    | 653      |
# |    total_timesteps | 201280   |
# | train/             |          |
# |    actor_loss      | 1.25     |
# |    critic_loss     | 5.03     |
# |    ent_coef        | 0.141    |
# |    ent_coef_loss   | -8.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6286     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.4     |
# |    ep_rew_mean     | 62.4     |
# | time/              |          |
# |    episodes        | 6700     |
# |    fps             | 307      |
# |    time_elapsed    | 663      |
# |    total_timesteps | 204352   |
# | train/             |          |
# |    actor_loss      | 1.06     |
# |    critic_loss     | 5.3      |
# |    ent_coef        | 0.138    |
# |    ent_coef_loss   | -7.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6382     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.5     |
# |    ep_rew_mean     | 65.1     |
# | time/              |          |
# |    episodes        | 6800     |
# |    fps             | 307      |
# |    time_elapsed    | 674      |
# |    total_timesteps | 207424   |
# | train/             |          |
# |    actor_loss      | 0.698    |
# |    critic_loss     | 4.61     |
# |    ent_coef        | 0.135    |
# |    ent_coef_loss   | -7.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6478     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.1     |
# |    ep_rew_mean     | 67.2     |
# | time/              |          |
# |    episodes        | 6900     |
# |    fps             | 307      |
# |    time_elapsed    | 684      |
# |    total_timesteps | 210624   |
# | train/             |          |
# |    actor_loss      | 0.24     |
# |    critic_loss     | 4.66     |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | -8.37    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6578     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.3     |
# |    ep_rew_mean     | 67       |
# | time/              |          |
# |    episodes        | 7000     |
# |    fps             | 307      |
# |    time_elapsed    | 695      |
# |    total_timesteps | 213888   |
# | train/             |          |
# |    actor_loss      | -0.632   |
# |    critic_loss     | 4.48     |
# |    ent_coef        | 0.13     |
# |    ent_coef_loss   | -7.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6680     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.7     |
# |    ep_rew_mean     | 67.5     |
# | time/              |          |
# |    episodes        | 7100     |
# |    fps             | 307      |
# |    time_elapsed    | 705      |
# |    total_timesteps | 216960   |
# | train/             |          |
# |    actor_loss      | -1.29    |
# |    critic_loss     | 4.59     |
# |    ent_coef        | 0.127    |
# |    ent_coef_loss   | -6.93    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6776     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.3     |
# |    ep_rew_mean     | 73       |
# | time/              |          |
# |    episodes        | 7200     |
# |    fps             | 307      |
# |    time_elapsed    | 715      |
# |    total_timesteps | 220256   |
# | train/             |          |
# |    actor_loss      | -1.47    |
# |    critic_loss     | 4.62     |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -6.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6879     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.9     |
# |    ep_rew_mean     | 70.3     |
# | time/              |          |
# |    episodes        | 7300     |
# |    fps             | 307      |
# |    time_elapsed    | 726      |
# |    total_timesteps | 223456   |
# | train/             |          |
# |    actor_loss      | -2.06    |
# |    critic_loss     | 4.78     |
# |    ent_coef        | 0.122    |
# |    ent_coef_loss   | -7.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6979     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.8     |
# |    ep_rew_mean     | 67.1     |
# | time/              |          |
# |    episodes        | 7400     |
# |    fps             | 307      |
# |    time_elapsed    | 736      |
# |    total_timesteps | 226560   |
# | train/             |          |
# |    actor_loss      | -2.7     |
# |    critic_loss     | 4.06     |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | -6.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7076     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.7     |
# |    ep_rew_mean     | 72.4     |
# | time/              |          |
# |    episodes        | 7500     |
# |    fps             | 307      |
# |    time_elapsed    | 746      |
# |    total_timesteps | 229728   |
# | train/             |          |
# |    actor_loss      | -3.17    |
# |    critic_loss     | 3.92     |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | -5.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7175     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.4     |
# |    ep_rew_mean     | 73.7     |
# | time/              |          |
# |    episodes        | 7600     |
# |    fps             | 307      |
# |    time_elapsed    | 757      |
# |    total_timesteps | 233024   |
# | train/             |          |
# |    actor_loss      | -3.18    |
# |    critic_loss     | 4.15     |
# |    ent_coef        | 0.115    |
# |    ent_coef_loss   | -6.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7278     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.8     |
# |    ep_rew_mean     | 76.9     |
# | time/              |          |
# |    episodes        | 7700     |
# |    fps             | 307      |
# |    time_elapsed    | 768      |
# |    total_timesteps | 236320   |
# | train/             |          |
# |    actor_loss      | -3.69    |
# |    critic_loss     | 4.21     |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -5.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7381     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.4     |
# |    ep_rew_mean     | 74.2     |
# | time/              |          |
# |    episodes        | 7800     |
# |    fps             | 307      |
# |    time_elapsed    | 779      |
# |    total_timesteps | 239616   |
# | train/             |          |
# |    actor_loss      | -4.56    |
# |    critic_loss     | 3.84     |
# |    ent_coef        | 0.11     |
# |    ent_coef_loss   | -6.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.4     |
# |    ep_rew_mean     | 74.7     |
# | time/              |          |
# |    episodes        | 7900     |
# |    fps             | 307      |
# |    time_elapsed    | 789      |
# |    total_timesteps | 242784   |
# | train/             |          |
# |    actor_loss      | -5.01    |
# |    critic_loss     | 3.83     |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | -5.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7583     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33       |
# |    ep_rew_mean     | 79.6     |
# | time/              |          |
# |    episodes        | 8000     |
# |    fps             | 307      |
# |    time_elapsed    | 800      |
# |    total_timesteps | 246080   |
# | train/             |          |
# |    actor_loss      | -5.45    |
# |    critic_loss     | 3.74     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -5.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7686     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.5     |
# |    ep_rew_mean     | 77.8     |
# | time/              |          |
# |    episodes        | 8100     |
# |    fps             | 307      |
# |    time_elapsed    | 810      |
# |    total_timesteps | 249408   |
# | train/             |          |
# |    actor_loss      | -5.65    |
# |    critic_loss     | 3.78     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -4.89    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7790     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.4     |
# |    ep_rew_mean     | 78.9     |
# | time/              |          |
# |    episodes        | 8200     |
# |    fps             | 307      |
# |    time_elapsed    | 821      |
# |    total_timesteps | 252576   |
# | train/             |          |
# |    actor_loss      | -6.4     |
# |    critic_loss     | 3.64     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -5.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7889     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.6     |
# |    ep_rew_mean     | 80.8     |
# | time/              |          |
# |    episodes        | 8300     |
# |    fps             | 307      |
# |    time_elapsed    | 832      |
# |    total_timesteps | 255936   |
# | train/             |          |
# |    actor_loss      | -6.51    |
# |    critic_loss     | 3.64     |
# |    ent_coef        | 0.101    |
# |    ent_coef_loss   | -4.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7994     |
# ...
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 44200    |
# |    fps             | 304      |
# |    time_elapsed    | 29819    |
# |    total_timesteps | 9066656  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 43.3     |
# |    ent_coef        | 0.0946   |
# |    ent_coef_loss   | -0.549   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 283329   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 44300    |
# |    fps             | 304      |
# |    time_elapsed    | 29978    |
# |    total_timesteps | 9115616  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 32.6     |
# |    ent_coef        | 0.093    |
# |    ent_coef_loss   | -0.314   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 284859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 44400    |
# |    fps             | 304      |
# |    time_elapsed    | 30137    |
# |    total_timesteps | 9164096  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 27.8     |
# |    ent_coef        | 0.0937   |
# |    ent_coef_loss   | -0.346   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 286374   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 44500    |
# |    fps             | 304      |
# |    time_elapsed    | 30304    |
# |    total_timesteps | 9215488  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 40.7     |
# |    ent_coef        | 0.0927   |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 287980   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 44600    |
# |    fps             | 304      |
# |    time_elapsed    | 30473    |
# |    total_timesteps | 9267232  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 68.6     |
# |    ent_coef        | 0.0916   |
# |    ent_coef_loss   | -0.127   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 289597   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 44700    |
# |    fps             | 304      |
# |    time_elapsed    | 30640    |
# |    total_timesteps | 9318592  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 55.9     |
# |    ent_coef        | 0.0929   |
# |    ent_coef_loss   | 0.535    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 291202   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 44800    |
# |    fps             | 304      |
# |    time_elapsed    | 30806    |
# |    total_timesteps | 9369312  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 49.7     |
# |    ent_coef        | 0.0921   |
# |    ent_coef_loss   | 0.499    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 292787   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 44900    |
# |    fps             | 304      |
# |    time_elapsed    | 30967    |
# |    total_timesteps | 9418784  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 34.3     |
# |    ent_coef        | 0.092    |
# |    ent_coef_loss   | -0.441   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 294333   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 45000    |
# |    fps             | 304      |
# |    time_elapsed    | 31128    |
# |    total_timesteps | 9468256  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 105      |
# |    ent_coef        | 0.0902   |
# |    ent_coef_loss   | -0.732   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 295879   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 45100    |
# |    fps             | 304      |
# |    time_elapsed    | 31288    |
# |    total_timesteps | 9517216  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 51.9     |
# |    ent_coef        | 0.0903   |
# |    ent_coef_loss   | 0.627    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 45200    |
# |    fps             | 304      |
# |    time_elapsed    | 31446    |
# |    total_timesteps | 9565696  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 37.4     |
# |    ent_coef        | 0.0912   |
# |    ent_coef_loss   | -0.967   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298924   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 45300    |
# |    fps             | 304      |
# |    time_elapsed    | 31614    |
# |    total_timesteps | 9617088  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 66.7     |
# |    ent_coef        | 0.0921   |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 300530   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 45400    |
# |    fps             | 304      |
# |    time_elapsed    | 31783    |
# |    total_timesteps | 9668832  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 71.8     |
# |    ent_coef        | 0.0921   |
# |    ent_coef_loss   | 0.179    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 302147   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 502      |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 45500    |
# |    fps             | 304      |
# |    time_elapsed    | 31951    |
# |    total_timesteps | 9720192  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 70.5     |
# |    ent_coef        | 0.0916   |
# |    ent_coef_loss   | -0.364   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 303752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 491      |
# |    ep_rew_mean     | 1.41e+03 |
# | time/              |          |
# |    episodes        | 45600    |
# |    fps             | 304      |
# |    time_elapsed    | 32113    |
# |    total_timesteps | 9769728  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 61.8     |
# |    ent_coef        | 0.0911   |
# |    ent_coef_loss   | -0.57    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 305300   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 501      |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 45700    |
# |    fps             | 304      |
# |    time_elapsed    | 32278    |
# |    total_timesteps | 9820160  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 53.7     |
# |    ent_coef        | 0.0926   |
# |    ent_coef_loss   | 0.41     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 306876   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 model.learn(
#       2     total_timesteps=int(5e7),
#       3     log_interval=100,
#       4     tb_log_name='direction',
#       5     reset_num_timesteps=False,
#       6 )
#
# File ~/anaconda3/lib/python3.9/site-packages/stable_baselines3/sac/sac.py:298, in SAC.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     285 def learn(
#     286     self,
#     287     total_timesteps: int,
#    (...)
#     295     reset_num_timesteps: bool = True,
#     296 ) -> OffPolicyAlgorithm:
# --> 298     return super().learn(
#     299         total_timesteps=total_timesteps,
#     300         callback=callback,
#     301         log_interval=log_interval,
#     302         eval_env=eval_env,
#     303         eval_freq=eval_freq,
#     304         n_eval_episodes=n_eval_episodes,
#     305         tb_log_name=tb_log_name,
#     306         eval_log_path=eval_log_path,
#     307         reset_num_timesteps=reset_num_timesteps,
#     308     )
#
# File ~/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:346, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     343 callback.on_training_start(locals(), globals())
#     345 while self.num_timesteps < total_timesteps:
# --> 346     rollout = self.collect_rollouts(
#     347         self.env,
#     348         train_freq=self.train_freq,
#     349         action_noise=self.action_noise,
#     350         callback=callback,
#     351         learning_starts=self.learning_starts,
#     352         replay_buffer=self.replay_buffer,
#     353         log_interval=log_interval,
#     354     )
#     356     if rollout.continue_training is False:
#     357         break
#
# File ~/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:579, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     576 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     578 # Rescale and perform action
# --> 579 new_obs, rewards, dones, infos = env.step(actions)
#     581 self.num_timesteps += env.num_envs
#     582 num_collected_steps += 1
#
# File ~/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:90, in Monitor.step(self, action)
#      88 if self.needs_reset:
#      89     raise RuntimeError("Tried to step environment that needs reset")
# ---> 90 observation, reward, done, info = self.env.step(action)
#      91 self.rewards.append(reward)
#      92 if done:
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/wrappers/time_limit.py:60, in TimeLimit.step(self, action)
#      48 def step(self, action):
#      49     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      50
#      51     Args:
#    (...)
#      57         "TimeLimit.truncated"=False if the environment terminated
#      58     """
#      59     observation, reward, terminated, truncated, info = step_api_compatibility(
# ---> 60         self.env.step(action),
#      61         True,
#      62     )
#      63     self._elapsed_steps += 1
#      65     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/wrappers/step_api_compatibility.py:52, in StepAPICompatibility.step(self, action)
#      43 def step(self, action):
#      44     """Steps through the environment, returning 5 or 4 items depending on `new_step_api`.
#      45
#      46     Args:
#    (...)
#      50         (observation, reward, terminated, truncated, info) or (observation, reward, done, info)
#      51     """
# ---> 52     step_returns = self.env.step(action)
#      53     if self.new_step_api:
#      54         return step_to_new_api(step_returns)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~/git/continuous_control-unitree-g1/environments/g1.py:348, in G1GoalDistanceEnv.step(self, action)
#     346 def step(self, action):
#     347     xy_position_before = self.get_body_com("trunk")[:2].copy()
# --> 348     self.do_simulation(action, self.frame_skip)
#     349     xy_position_after = self.get_body_com("trunk")[:2].copy()
#     351     xy_velocity = (xy_position_after - xy_position_before) / self.dt
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_env.py:177, in BaseMujocoEnv.do_simulation(self, ctrl, n_frames)
#     175 if np.array(ctrl).shape != self.action_space.shape:
#     176     raise ValueError("Action dimension mismatch")
# --> 177 self._step_mujoco_simulation(ctrl, n_frames)
#
# File ~/anaconda3/lib/python3.9/site-packages/gym/envs/mujoco/mujoco_env.py:390, in MujocoEnv._step_mujoco_simulation(self, ctrl, n_frames)
#     387 def _step_mujoco_simulation(self, ctrl, n_frames):
#     388     self.data.ctrl[:] = ctrl
# --> 390     mujoco.mj_step(self.model, self.data, nstep=self.frame_skip)
#     392     # As of MuJoCo 2.0, force-related quantities like cacc are not computed
#     393     # unless there's a force sensor in the model.
#     394     # See https://github.com/openai/gym/issues/1541
#     395     mujoco.mj_rnePostConstraint(self.model, self.data)
#
# KeyboardInterrupt:

# %%
model.save("trained_models/direction")
